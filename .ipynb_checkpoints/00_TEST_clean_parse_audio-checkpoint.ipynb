# %%
# pip install --upgrade google-cloud-speech
import os
import io
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from pydub import AudioSegment
import pandas as pd
import time

# %%
# Check audio file properites
sound_file = AudioSegment.from_file('./Datasets/TEST_samples/sample1.wav', format="wav")

print(f'Sample Width: {sound_file.sample_width}')
print(f'Channel Count: {sound_file.channels}')
print(f'Duration: {len(sound_file) / 1000}s')
print(f'Sample Rate: {sound_file.frame_rate}')
print(f'Sample Rate: {sound_file.dBFS}')
# Out:
# Sample Width: 2
# Channel Count: 1
# Duration: 9.854s
# Sample Rate: 22050
# Sample Rate: -28.164799306236986

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/alex/ga-dsi-11/police-scanner-speech-to-text-c09b11750e4e.json'
client = speech.SpeechClient()

df = pd.DataFrame()
total_time_start = time.time()
for i in os.listdir('./Datasets/TEST_samples/'):
    if i.endswith('.wav'):
        loop_time = time.time()
        with io.open(f'./Datasets/TEST_samples/{i}', 'rb') as audio_file:
            content = audio_file.read()
            audio = speech.types.RecognitionAudio(content=content)
        print(f"File {i} opened")
        config = speech.types.RecognitionConfig(
            encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
            sample_rate_hertz=22050,
            language_code='en-US',
            audio_channel_count=1,
            enable_separate_recognition_per_channel = True,
            use_enhanced = True,
            model = 'phone_call',
            speech_contexts= [{'boost': 20.0}])
        
        response = client.recognize(config, audio)
        for result in response.results:
            d = {}
            d['transcript'] = result.alternatives[0].transcript
            d['confidence_interval'] = result.alternatives[0].confidence
            d['file_name'] = i
            df = df.append(d, ignore_index=True)
            print(f"File {i} results added to dataframe: {time.time() - loop_time}s")
        

print(f"Total time elapsed: {time.time() - total_time_start}s")
# Out:
# File sample11.wav opened
# File sample11.wav processed
# File sample11.wav results added to dataframe
# Took 9.391078233718872s to process
# File sample11.wav results added to dataframe
# Took 9.397046089172363s to process
# File sample10.wav opened
# File sample10.wav processed
# File sample12.wav opened
# File sample12.wav processed
# File sample12.wav results added to dataframe
# Took 4.6144468784332275s to process
# File sample13.wav opened
# File sample13.wav processed
# File sample13.wav results added to dataframe
# Took 2.8722410202026367s to process
# File sample17.wav opened
# File sample17.wav processed
# File sample17.wav results added to dataframe
# Took 11.489796161651611s to process
# File sample16.wav opened
# File sample16.wav processed
# File sample16.wav results added to dataframe
# Took 10.83010196685791s to process
# File sample16.wav results added to dataframe
# Took 10.836151838302612s to process
# File sample14.wav opened
# File sample14.wav processed
# File sample14.wav results added to dataframe
# Took 13.001296997070312s to process
# File sample14.wav results added to dataframe
# Took 13.00838303565979s to process
# File sample15.wav opened
# File sample15.wav processed
# File sample15.wav results added to dataframe
# Took 8.695762872695923s to process
# File sample12loud.wav opened
# File sample12loud.wav processed
# File sample12loud.wav results added to dataframe
# Took 7.5973219871521s to process
# File sample12compressdynamicrange.wav opened
# File sample12compressdynamicrange.wav processed
# File sample12compressdynamicrange.wav results added to dataframe
# Took 6.1228978633880615s to process
# File sample12removeddcoffset.wav opened
# File sample12removeddcoffset.wav processed
# File sample12removeddcoffset.wav results added to dataframe
# Took 5.657618999481201s to process
# File sample18.wav opened
# File sample18.wav processed
# File sample18.wav results added to dataframe
# Took 14.107735872268677s to process
# File sample19.wav opened
# File sample19.wav processed
# File sample19.wav results added to dataframe
# Took 3.289191961288452s to process
# File sample2.wav opened
# File sample2.wav processed
# File sample2.wav results added to dataframe
# Took 14.837370872497559s to process
# File sample2.wav results added to dataframe
# Took 14.845800876617432s to process
# File sample22.wav opened
# File sample22.wav processed
# File sample22.wav results added to dataframe
# Took 11.78150200843811s to process
# File sample1.wav opened
# File sample1.wav processed
# File sample1.wav results added to dataframe
# Took 8.789963006973267s to process
# File sample21.wav opened
# File sample21.wav processed
# File sample21.wav results added to dataframe
# Took 13.040156841278076s to process
# File sample20.wav opened
# File sample20.wav processed
# File sample20.wav results added to dataframe
# Took 6.2252418994903564s to process
# Total time elapsed: 154.30716013908386s

# %%
df
# Out:
#     confidence_interval                         file_name  \
# 0              0.811442                      sample11.wav
# 1              0.727310                      sample11.wav
# 2              0.664993                      sample12.wav
# 3              0.535080                      sample13.wav
# 4              0.773811                      sample17.wav
# 5              0.705214                      sample16.wav
# 6              0.781541                      sample16.wav
# 7              0.912839                      sample14.wav
# 8              0.609282                      sample14.wav
# 9              0.659719                      sample15.wav
# 10             0.540075                  sample12loud.wav
# 11             0.556405  sample12compressdynamicrange.wav
# 12             0.636313       sample12removeddcoffset.wav
# 13             0.752900                      sample18.wav
# 14             0.600289                      sample19.wav
# 15             0.685525                       sample2.wav
# 16             0.555013                       sample2.wav
# 17             0.787455                      sample22.wav
# 18             0.758835                       sample1.wav
# 19             0.658115                      sample21.wav
# 20             0.756485                      sample20.wav
#
#                                            transcript
# 0   a lot of static respiratory distress 1089 Dorc...
# 1                                    anyone returning
# 2       play water at 8:10 a.m. our colorful Longwood
# 3                                Saturday 72nd Street
# 4   nineteen eighty-two and the cardiac Florida 11...
# 5                          24 monitor comments please
# 6    I meant probably have one for you two stroke ...
# 7                                                okay
# 8    495 North Friday the Thirteenth battling the ...
# 9   495 North despite a 13 sat on the 1st and 2nd ...
# 10      play water at 8:10 a.m. our colorful Wildwood
# 11            playlist at 8:10 a.m. colorful Longwood
# 12            26th at 8:10 a.m. our colorful Longwood
# 13  cardiac disorders 1190 Adams Street Dorchester...
# 14                  that can come out from a district
# 15     to advise the Rocksino and orange alert system
# 16                                   hi Miranda. What
# 17                                      question mark
# 18  4th and eleven fifty hours in recent years Sev...
# 19    1515 hold on Truxel Vania Avenue in Crown Point
# 20  but individual running away from try to catch ...

# %%
# # Load in audio file
# segment = AudioSegment.from_wav('./Datasets/sample_audio2/sample12.wav')

# # loud
# response.results

# # Make it louder
# louder_segment = segment +10
# louder_segment.export(f"./Datasets/TEST_samples/sample12loud.wav", format = "wav")

# #
# compressed_audio = segment.compress_dynamic_range(threshold=segment.dBFS)
# compressed_audio.export(f"./Datasets/TEST_samples/sample12compressdynamicrange.wav", format = "wav")

# removeddcoffset = segment.remove_dc_offset()
# removeddcoffset.export(f"./Datasets/TEST_samples/sample12removeddcoffset.wav", format = "wav")

# normailzed = segment.normalize(headroom=0.5)
# normailzed

# # clean_segment = AudioSegment.from_wav('./Datasets/sample_audio/sample5clean.wav')
# # clean_segment

# code for single audio file

# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/alex/ga-dsi-11/police-scanner-speech-to-text-c09b11750e4e.json'
# client = speech.SpeechClient()

# with io.open('./Datasets/sample_audio2/sample12.wav', 'rb') as audio_file:
#     content = audio_file.read()
#     audio = speech.types.RecognitionAudio(content=content)

# config = speech.types.RecognitionConfig(
#     encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
#     sample_rate_hertz=22050,
#     language_code='en-US',
#     audio_channel_count=1,
#     enable_separate_recognition_per_channel = True,
#     use_enhanced = True,
#     model = 'phone_call',
#     speech_contexts= [{'boost': 20.0}]
# )

# response = client.recognize(config, audio)
# for result in response.results:
#     print(result.alternatives[0].transcript)
#     print(result.alternatives[0].confidence)

# df = pd.DataFrame()

# d = {}
# d['transcript'] = result.alternatives[0].transcript
# d['confidence_interval'] = result.alternatives[0].confidence
# d['file_name'] = "TESTESTTEST"

# df.append(d, ignore_index=True)

# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/alex/ga-dsi-11/police-scanner-speech-to-text-c09b11750e4e.json'
# client = speech.SpeechClient()


# with io.open('./Datasets/TEST_samples/sample1.wav', 'rb') as audio_file:
#     content = audio_file.read()
#     audio = speech.types.RecognitionAudio(content=content)

# config = speech.types.RecognitionConfig(
#     encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
#     sample_rate_hertz=22050,
#     language_code='en-US',
#     audio_channel_count=1,
#     enable_separate_recognition_per_channel = True,
#     use_enhanced = True,
#     model = 'phone_call',
#     speech_contexts= [{'boost': 20.0}]
# )

# response = client.recognize(config, audio)
# # for result in response.results:
# print(result.alternatives[0].transcript)
# print(result.alternatives[0].confidence)
# #     if len(result.alternatives[0].transcript) > 0:
# d = {}
# d['transcript'] = result.alternatives[0].transcript
# d['confidence_interval'] = result.alternatives[0].confidence
# d['file_name'] = "i"
# print(d)
# df = df.append(d, ignore_index=True)
# # for result in response.results:
# #     print(result.alternatives[0].transcript)
# #     print(result.alternatives[0].confidence)

# # df = pd.DataFrame()

# # d = {}
# # d['transcript'] = result.alternatives[0].transcript
# # d['confidence_interval'] = result.alternatives[0].confidence
# # d['file_name'] = "TESTESTTEST"

# # df.append(d, ignore_index=True)
