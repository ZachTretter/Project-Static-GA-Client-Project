# %%
import pandas as pd

# %%
# Source - http://www.bearcat1.com/radioma.htm
# Pulled 06 May 2020

df_police_codes = pd.read_csv("policecodes.csv")

# %%
df_police_codes.head()
# Out:
#       type code alphabet                   meaning
# 0  Service    1      NaN       Vehicle maintenance
# 1  Service    2      NaN  Radio maintenance/repair
# 2  Service    3      NaN                  Training
# 3  Service    4      NaN     Transporting a female
# 4  Service    5      NaN   Transporting a prisoner

# %%
code_dict = df_police_codes.to_dict()

# %%
code_dict['meaning'][17]
# Out:
# 'At shooting range'

# %%
# View the entire thing
pd.set_option("display.max_rows", None, "display.max_columns", None)
df_police_codes
# Out:
#            type     code alphabet  \
# 0       Service        1      NaN
# 1       Service        2      NaN
# 2       Service        3      NaN
# 3       Service        4      NaN
# 4       Service        5      NaN
# 5       Service        6      NaN
# 6       Service        7      NaN
# 7       Service        8      NaN
# 8       Service        9      NaN
# 9       Service       10      NaN
# 10      Service       11      NaN
# 11      Service       12      NaN
# 12      Service       13      NaN
# 13      Service       14      NaN
# 14      Service       15      NaN
# 15      Service       16      NaN
# 16      Service       17      NaN
# 17      Service       18      NaN
# 18      Service       19      NaN
# 19      Service       20      NaN
# 20      Service       21      NaN
# 21      Service       22      NaN
# 22      Service       23      NaN
# 23      Service       24      NaN
# 24      Service       25      NaN
# 25      Service       26      NaN
# ...
