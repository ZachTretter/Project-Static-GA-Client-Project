# %% [markdown]
# DSI BOS 11 (May 2020) Project 5
#
# Alex Golden, Jungmoon Ham, Luke Podsiadlo, Zach Tretter
#
# Workbook 6 - Mapping
#
# ----------

# %% [markdown]
# ## Geocode and Map Addresses from Police Radio Speech-to-Text
#
# Relevance to Problem Statement : _"The tool will flag neighborhoods or specific streets where the police and first-respondents were called to provide assistance related to the event."_
#
# #### Workflow Steps
#
# 1. Import dataframe.  Addresses at minimum data, additional context as avaiable
#
# 2. Find Latitude/Longitude from address ("geocode") via google to enable plotting on map
#
# 3. Visualize on map using [Folium](https://python-visualization.github.io/folium/)
#
#
# Note : The geocodes are already loaded

# %% [markdown]
# #### API Key (Google Geocoding API)

# %%
# Text String from Google
my_key = ""

# %%
# geocodes from submission run
boston_geocodes = pd.read_csv("../DATASETS/geocodes/boston_geocodes.csv").drop(columns = ["Unnamed: 0"])
boston_geocodes['geocode'] = boston_geocodes.apply(tuple,axis=1)

watertown_geocodes = pd.read_csv("../DATASETS/geocodes/watertown_geocodes.csv").drop(columns = ["Unnamed: 0"])
watertown_geocodes['geocode'] = watertown_geocodes.apply(tuple,axis=1)

# %% [markdown]
# _____________
#
# ## Imports

# %%
import pandas as pd
import numpy as np
import requests

# !pip install folium
import folium

# %% [markdown]
# ### Import Dataframe

# %%
## Import
df = pd.read_csv("../DATASETS/dataframe_final.csv")

# %%
# Drop columns as desired
df = df.drop(columns = ["Unnamed: 0",
                        'tokens',
                        'streets',
                        'numbers'])

# %%
def str_to_list(x):
    x = x.replace("[","")
    x = x.replace("]","")
    x = x.replace("'","")
    x = x.strip()
    x = x.split(",")
    return x

# %%
df['full_streets']=df['full_streets'].map(str_to_list)

# %%
# Rearrange columns as needed
df = df[['confidence',
         'file_name',
         'dolby',
         'full_streets',
         'transcript']]

# %%
df_boston = df[(df['file_name']!='watertown_manhunt') & 
               (df['dolby']==False)].copy()

df_watertown = df[df['file_name']=='watertown_manhunt'].copy()

# %% [markdown]
# ### Function that Finds Latitude and Longitude from Address
#
# Function code adapted from [article on geocoding written by Shane Lynn](https://www.shanelynn.ie/batch-geocoding-in-python-with-google-geocoding-api/)
#
# Given an address, this code will create a URL to query google.
#
# It will return this dictionary
#
# | Key                 | Value             | Information                                              |
# |---------------------|-------------------|----------------------------------------------------------|
# | lat_long            | tuple (lat, long) | Geocode result from google                               |
# | full_output_address | Text String       | Full address corresponding to geocode returned by google |
# | input_string        | Text String       | String that was searched on (from dataframe)             |
# | number_of_results   | Integer           | Number of results                                        |
# | status              | Text String       | 'Ok' if request successful<br>None otherwise             |

# %%
def get_google_latlong(address,
                       api_key=my_key,
                       return_full_response=False):
    
    # Create the URL for geocoding
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    
    # Add the API key
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the results:
    results = requests.get(geocode_url)
    
    # Display results as JSON dictionary
    results = results.json()

    # If no result, return None
    if len(results['results']) == 0:
        output = {
            "lat_long":(False)
        }
        
    else:    
        answer = results['results'][0]
        output = { "lat_long" : (
            answer.get('geometry').get('location').get('lat'),
            answer.get('geometry').get('location').get('lng')
        )
                 }
        
        output['full_output_address'] = answer.get('formatted_address')
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')

    if return_full_response is True:
        output['response'] = results
    
    return output

# %% [markdown]
# ## Folium Map - Watertown Manhunt Transcript

# %%
df_watertown.head(3)
# Out:
#     confidence          file_name  dolby  \
# 474     manual  watertown_manhunt  False
# 475     manual  watertown_manhunt  False
# 476     manual  watertown_manhunt  False
#
#                                           full_streets  \
# 474  [816 Station,  816 The,  816 Middle,  816 Memo...
# 475                                          [609 The]
# 476                              [94 Long,  94 Spruce]
#
#                                             transcript
# 474  One 5'7", the second with darker skin, both su...
# 475     Is there an officer driving the 609 right now?
# 476  Shots Fired! Shots Fired! Officers pinned down...

# %%
# Build a list of addresses
watertown_address_list = []
for row in df_watertown['full_streets']:
    for i in row:
        watertown_address_list += [[i, 'Watertown MA']]

# Display first 5 elements
watertown_address_list[:5]
# Out:
# [['816 Station', 'Watertown MA'],
#  [' 816 The', 'Watertown MA'],
#  [' 816 Middle', 'Watertown MA'],
#  [' 816 Memorial', 'Watertown MA'],
#  [' 816 Black', 'Watertown MA']]

# %% [markdown]
# --------
#
# ### Note - The below cell costs money to run!

# %%
# Build a list of geocoded addresses
watertown_lat_long_list = []
for i in watertown_address_list:
    j = get_google_latlong(i)['lat_long']
    print(i,j)
    if j:
        watertown_lat_long_list += [j]
# Out:
# ['816 Memorial', 'Watertown MA'] (42.3613221, -71.11567699999999)
# [' 816 Black', 'Watertown MA'] (42.364476, -71.181772)
# [' 816 Drive', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 816 Eastern', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 816 The', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 816 Cambridge', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 816 Middle', 'Watertown MA'] (42.3693591, -71.1908705)
# [' 816 Station', 'Watertown MA'] (42.3709299, -71.1828321)
# ['609 The', 'Watertown MA'] (42.3709299, -71.1828321)
# ['94 Long', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 94 Spruce', 'Watertown MA'] (42.3668022, -71.1701717)
# ['111 Dexter', 'Watertown MA'] (42.36681919999999, -71.16280909999999)
# [' 111 Hazel', 'Watertown MA'] (42.3675637, -71.1649596)
# ['94 Long', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 94 Spruce', 'Watertown MA'] (42.3668022, -71.1701717)
# ['982', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Watertown', 'Watertown MA'] (42.3709299, -71.1828321)
# ['1181 Lincoln', 'Watertown MA'] (42.3685338, -71.1723614)
# [' 1181 Spruce', 'Watertown MA'] (42.367661, -71.1709892)
# ['13', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Dexter', 'Watertown MA'] (42.366843, -71.1627798)
# [' 13', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Laurel', 'Watertown MA'] (42.3661366, -71.1631707)
# [' 13', 'Watertown MA'] (42.3709299, -71.1828321)
# [' The', 'Watertown MA'] (42.3709299, -71.1828321)
# ['2 Spruce', 'Watertown MA'] (42.3699272, -71.1716211)
# ['543 The', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 543 Auburn', 'Watertown MA'] (42.3709299, -71.1828321)
# ['144 Dexter', 'Watertown MA'] (42.3658764, -71.1636271)
# [' 144 Laurel', 'Watertown MA'] (42.366209, -71.15998499999999)
# ['144 Dexter', 'Watertown MA'] (42.3658764, -71.1636271)
# ['19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' The', 'Watertown MA'] (42.3709299, -71.1828321)
# ['526 Spruce', 'Watertown MA'] (42.367661, -71.1709892)
# [' 526 Auburn', 'Watertown MA'] (42.3669879, -71.1806122)
# [' 526 The', 'Watertown MA'] (42.3709299, -71.1828321)
# [' 526 Upland', 'Watertown MA'] (42.3712996, -71.1611377)
# ['526 Auburn', 'Watertown MA'] (42.3669879, -71.1806122)
# ['19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Auburn', 'Watertown MA'] (42.3671488, -71.18127009999999)
# [' 19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Dexter', 'Watertown MA'] (42.366843, -71.1627798)
# [' 19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Laurel', 'Watertown MA'] (42.3661366, -71.1631707)
# [' 19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' Upland', 'Watertown MA'] (42.3712996, -71.1611377)
# [' 19', 'Watertown MA'] (42.3709299, -71.1828321)
# [' The', 'Watertown MA'] (42.3709299, -71.1828321)

# %% [markdown]
# ### Note - The above cell costs money to run!
#
# -------------

# %%
watertown_lat_long_list = watertown_geocodes['geocode']

# %%
# Create a Folium Object (Centered at Harvard Square)
m = folium.Map(
    location = [42.3736, -71.1190],
    tiles = 'Stamen Terrain',
    zoom_start = 12,
    control_scale=False
)

# Iterate though our list of latitude and longitudes
for i in watertown_lat_long_list:
    folium.CircleMarker(
    radius = 10,
    location = i,
    color ='red'
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# -----------

# %% [markdown]
# ## Folium Map - Boston Metro Police 01 May 2020 to 02 May 2020

# %%
df_boston.head(3)
# Out:
#     confidence                           file_name  \
# 0  0.692421913    sample92-25818-20200501-0941.wav
# 1  0.659736931    sample52-25818-20200501-1240.wav
# 2  0.726749361  sample1232-25818-20200501-1310.wav
#
#                                 full_streets  \
# 0                              [19219 South]
# 1  [495 1st,  495 North,  495 The,  495 2nd]
# 2                [373 Avenue,  373 Highland]
#
#                                           transcript
# 0        having a t show jokes to 19219 South Street
# 1  495 North despite a 13 sat on the 1st and 2nd ...
# 2  Island, 47th Street. Our address is 7173 Highl...

# %%
# Build a list of addresses
boston_address_list = []
for row in df_boston['full_streets']:
    for i in row:
        boston_address_list += [[i, 'Massachusetts']]

len(boston_address_list)
# Out:
# 1481

# %% [markdown]
# -----------
#
# ### Note - The below cell costs money to run!

# %%
# Build a list of geocoded addresses
boston_lat_long_list = []
for index,i in enumerate(boston_address_list):
    j = get_google_latlong(i)['lat_long']
    if j:
        boston_lat_long_list += [j]
    if index % 10 == 0 :
        print(i,j)
# Out:
# ['19219 South', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3831 Ellis', 'Massachusetts'] (42.4211198, -71.0676361)
# [' 342 Hanover', 'Massachusetts'] (42.3649691, -71.0535143)
# [' 1 Lyman', 'Massachusetts'] (42.3198318, -71.61289169999999)
# ['81 Essex', 'Massachusetts'] (42.3524171, -71.060316)
# [' 120 Newton', 'Massachusetts'] (42.3313461, -71.2463017)
# [' 1929 Avenue', 'Massachusetts'] (42.4072107, -71.3824374)
# ['on Hatch', 'Massachusetts'] (42.1276832, -71.5201393)
# [' 269 Cross', 'Massachusetts'] (42.4664118, -71.1360065)
# [' 87 East', 'Massachusetts'] (42.1132377, -71.6547507)
# [' 1190 The', 'Massachusetts'] (42.3240969, -71.0641998)
# [' 1792 Warren', 'Massachusetts'] (42.2125423, -72.19118499999999)
# [' 780 Albany', 'Massachusetts'] (42.3337186, -71.0725726)
# [' 11279 Father', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 1311 Boston', 'Massachusetts'] (42.359595, -71.062193)
# ['2126 Albany', 'Massachusetts'] (42.6525793, -73.7562317)
# ['9 Still', 'Massachusetts'] (41.9046305, -70.2408325)
# [' 132 Central', 'Massachusetts'] (42.1398804, -71.516476)
# [' 132 Boylston', 'Massachusetts'] (42.35229349999999, -71.06600329999999)
# [' 367 Walker', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 2159 Luther', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 1 Seven', 'Massachusetts'] (42.4754623, -71.2064896)
# ['431 Well', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 23 Station', 'Massachusetts'] (42.3366467, -71.0894067)
# [' 4143 Boston', 'Massachusetts'] (42.3600825, -71.0588801)
# [' 1733 Boston', 'Massachusetts'] (42.63535830000001, -71.3538186)
# ['25 Wesley', 'Massachusetts'] (42.027118, -71.452153)
# [' 196 South', 'Massachusetts'] (42.15620759999999, -71.03577829999999)
# [' 5150 West', 'Massachusetts'] (42.34535839999999, -72.8988069)
# [' 15 The', 'Massachusetts'] (42.12783719999999, -72.627833)
# ['One Way', 'Massachusetts'] (42.3282698, -71.0723567)
# [' one Way', 'Massachusetts'] (42.3282698, -71.0723567)
# [' 215 Beach', 'Massachusetts'] (42.2917663, -70.87449)
# [' 24 River', 'Massachusetts'] (42.6245685, -71.1577787)
# [' 94360 Off', 'Massachusetts'] (42.3311111, -71.08)
# ['1871 Dorchester', 'Massachusetts'] (42.30163049999999, -71.067605)
# [' 5528 Park', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 46 Hyde', 'Massachusetts'] (42.4144971, -72.7906761)
# [' 5193 Washington', 'Massachusetts'] (42.36592, -73.116214)
# [' 35 Red', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 1354 Cambridge', 'Massachusetts'] (42.3736158, -71.10973349999999)
# [' 1621 Market', 'Massachusetts'] (42.4072107, -71.3824374)
# ['40 The', 'Massachusetts'] (42.504717, -71.1961255)
# [' 17th Hamilton', 'Massachusetts'] (42.63620520000001, -70.8431049)
# [' 141 Well', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 724 Preble', 'Massachusetts'] (42.4072107, -71.3824374)
# ['70 South', 'Massachusetts'] (42.3340959, -71.06633219999999)
# [' 509 The', 'Massachusetts'] (42.3389118, -71.5951278)
# [' 3211 Lincoln', 'Massachusetts'] (42.4259283, -71.3039469)
# [' 145 South', 'Massachusetts'] (42.3051409, -71.11488779999999)
# [' 39 Snow', 'Massachusetts'] (42.53249599999999, -71.4408129)
# [' 120 Boston', 'Massachusetts'] (42.3455793, -71.0997866)
# [' 4262 Georgetown', 'Massachusetts'] (42.7250918, -70.99116590000001)
# [' 391 Seaver', 'Massachusetts'] (42.3036184, -71.0819738)
# [' 1175 Field', 'Massachusetts'] (42.366519, -71.1345059)
# [' 1567 Boston', 'Massachusetts'] (42.3600825, -71.0588801)
# [' 729 Red', 'Massachusetts'] (42.4072107, -71.3824374)
# ['39 Seven', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 17511 West', 'Massachusetts'] (42.34535839999999, -72.8988069)
# [' 100 Boston', 'Massachusetts'] (42.3466841, -71.0656551)
# ['167 The', 'Massachusetts'] (42.2932956, -71.604248)
# ['1642 Shawmut', 'Massachusetts'] (42.4072107, -71.3824374)
# ['1875 Avenue', 'Massachusetts'] (42.4483811, -71.22966389999999)
# ['7 Everett', 'Massachusetts'] (42.4200918, -71.05398199999999)
# [' 43 South', 'Massachusetts'] (42.3399568, -71.15761630000002)
# ['25 Off', 'Massachusetts'] (42.5193972, -71.7007362)
# ['7507 The', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 9 West', 'Massachusetts'] (42.269357, -72.200446)
# ['13 Station', 'Massachusetts'] (42.12285869999999, -71.18056849999999)
# [' 24 Canal', 'Massachusetts'] (42.216586, -72.6031278)
# [' 714 Commonwealth', 'Massachusetts'] (42.3495529, -71.1056499)
# [' 911 The', 'Massachusetts'] (41.9121726, -70.9603473)
# [' 5114 Brighton', 'Massachusetts'] (42.3463503, -71.1626756)
# [' 37 Red', 'Massachusetts'] (42.4072107, -71.3824374)
# [' I South', 'Massachusetts'] (41.6482217, -70.8876744)
# [' seven Beacon', 'Massachusetts'] (42.3358733, -71.15249399999999)
# [' Fox23 The', 'Massachusetts'] (42.4072107, -71.3824374)
# ['383 Talbot', 'Massachusetts'] (42.2900199, -71.07090769999999)
# [' 3113 Dorchester', 'Massachusetts'] (42.30163049999999, -71.067605)
# ['2837 Carol', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 2948 West', 'Massachusetts'] (42.34535839999999, -72.8988069)
# ['2933 Green', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 7136 Central', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 239 Boston', 'Massachusetts'] (42.3446, -71.08019999999999)
# [' 1190 Adams', 'Massachusetts'] (42.2718952, -71.0660729)
# ['5 Grand', 'Massachusetts'] (42.4072107, -71.3824374)
# ['1401 Ellsworth', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 6165 Red', 'Massachusetts'] (42.4015007, -71.08163449999999)
# [' 43 Causeway', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 44 Black', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 360 Lafayette', 'Massachusetts'] (42.4072107, -71.3824374)
# ['1000 Market', 'Massachusetts'] (42.2806473, -71.6734495)
# [' 850 Boston', 'Massachusetts'] (42.34426879999999, -71.0305676)
# ['2207 Boston', 'Massachusetts'] (42.151124, -72.46365300000001)
# [' 2521 Green', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3726 Way', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 160 Austin', 'Massachusetts'] (42.2644447, -71.1256574)
# ['261 Highland', 'Massachusetts'] (42.3915875, -71.1106685)
# [' 13 Dorchester', 'Massachusetts'] (42.2517183, -71.7970398)
# [' 21 Saratoga', 'Massachusetts'] (42.3758399, -71.0380998)
# [' 4172 Charlestown', 'Massachusetts'] (42.3782065, -71.0602131)
# [' 7236 The', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 40151 Worcester', 'Massachusetts'] (42.2625932, -71.8022934)
# ['51430 Federal', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3 Jason', 'Massachusetts'] (42.331751, -71.0445952)
# [' 16670 Red', 'Massachusetts'] (42.4015007, -71.08163449999999)
# [' 795 Hyde', 'Massachusetts'] (42.2565289, -71.1240559)
# ['5274 Everett', 'Massachusetts'] (42.40843, -71.0536625)
# [' 14 Sterling', 'Massachusetts'] (42.1181074, -72.7626324)
# ['916 Old', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 1201 Washington', 'Massachusetts'] (42.1888216, -71.44021)
# [' 157 Washington', 'Massachusetts'] (42.2265866, -71.3899291)
# ['11:21 The', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 597 South', 'Massachusetts'] (42.248225, -71.06990809999999)
# ['219 Court', 'Massachusetts'] (42.4072107, -71.3824374)
# ['60 Broadway', 'Massachusetts'] (42.1162309, -70.8115013)
# ['2117 South', 'Massachusetts'] (47.5882487, -122.3043363)
# [' 232 Circle', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 459 Park', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 335 3rd', 'Massachusetts'] (42.4072107, -71.3824374)
# ['426 Washington', 'Massachusetts'] (42.6339739, -70.6756821)
# [' 426 Cross', 'Massachusetts'] (42.34651530000001, -71.7119328)
# ['17219 Beech', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3572 Central', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 11443 5th', 'Massachusetts'] (47.500758, -122.340919)
# [' 339 Dorchester', 'Massachusetts'] (42.3309827, -71.0544893)
# [' 790 Well', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3726 Well', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 151 Hyde', 'Massachusetts'] (42.2565289, -71.1240559)
# [' 113 Drive', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 42 Robin', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 42 Boston', 'Massachusetts'] (42.3144895, -71.1037888)
# [' 587 Newbury', 'Massachusetts'] (42.3505082, -71.0770399)
# [' 1251 Richmond', 'Massachusetts'] (42.3729519, -73.3676804)
# [' 106 Albert', 'Massachusetts'] (42.4072107, -71.3824374)
# ['1595 Brighton', 'Massachusetts'] (42.3393339, -71.1337547)
# [' 92 Hudson', 'Massachusetts'] (42.3526252, -71.55665440000001)
# [' 21', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3150 The', 'Massachusetts'] (42.275308, -71.748187)
# ['5350 Off', 'Massachusetts'] (42.3055488, -71.3609194)
# [' 1537 Red', 'Massachusetts'] (42.4072107, -71.3824374)
# ['on Dale', 'Massachusetts'] (42.3351874, -73.2463113)
# ['1179 Fulton', 'Massachusetts'] (42.3623975, -71.0531638)
# [' 59 Audubon', 'Massachusetts'] (42.4093993, -71.3317636)
# [' 51 Red', 'Massachusetts'] (42.4072107, -71.3824374)
# [' 3467 Off', 'Massachusetts'] (42.3311111, -71.08)
# [' 255 Northampton', 'Massachusetts'] (42.3356669, -72.6739083)
# ['32032 Hyde', 'Massachusetts'] (42.2565289, -71.1240559)
# [' 104 1st', 'Massachusetts'] (42.4072107, -71.3824374)

# %% [markdown]
# ### Note - The above cell costs money to run!
#
# --------

# %%
boston_lat_long_list = boston_geocodes['geocode']

# %%
# Create a Folium Object (Centered at Harvard Square)
m = folium.Map(
    location = [42.3736, -71.1190],
    tiles = 'Stamen Terrain',
    zoom_start = 12,
    control_scale=False
)

# Iterate though our list of latitude and longitudes
for i in boston_lat_long_list:
    folium.CircleMarker(
    radius = 2,
    location = i,
    color ='red'
    ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
