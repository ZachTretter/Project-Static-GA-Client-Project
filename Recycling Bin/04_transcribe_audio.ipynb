# %%
# pip install --upgrade google-cloud-speech
import os
import io
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from pydub import AudioSegment
import pandas as pd
import time

# %%
# Check audio file properites
# sound_file = AudioSegment.from_file('./Datasets/sample_audio/QUICKTEST/31120-20200501-0034sample21.wav', format="wav")

# print(f'Sample Width: {sound_file.sample_width}')
# print(f'Channel Count: {sound_file.channels}')
# print(f'Duration: {len(sound_file) / 1000}s')
# print(f'Sample Rate: {sound_file.frame_rate}')
# print(f'Sample Rate: {sound_file.dBFS}')

# %%
def transcribe(input_path,output_path,output_filename,street_file):
    # define key path (security feature)
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/alex/ga-dsi-11/police-scanner-speech-to-text-c09b11750e4e.json'
    
    # Instantiate speech to text model, DataFrame, and time
    client = speech.SpeechClient()
    df = pd.DataFrame()
    total_time_start = time.time()
    
    # List of streets
    street_df = pd.read_csv(street_file)
    street_list = []
    for j in street_df['0']:
        street_list.append(j) 
        
    
    # loop through files in our input path
    for i in os.listdir(input_path):
        if i.endswith('.wav'):
            loop_time = time.time()
            
            # open our audio file
            with io.open(f'{input_path}{i}', 'rb') as audio_file:
                content = audio_file.read()
                audio = speech.types.RecognitionAudio(content=content)
            print(f"File {i} opened")
            
            # model parameters
            config = speech.types.RecognitionConfig(
                encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
                sample_rate_hertz = 22050,
                language_code = 'en-US',
                audio_channel_count = 1,
                enable_separate_recognition_per_channel = True,
                use_enhanced = True,
                model = 'phone_call',
                speech_contexts = [{'boost': 20.0}])
            
            # This models equivalent of fit/predict
            response = client.recognize(config, audio)
            
            # build dictionary -> dataframe
            print(response.results)
            for result in response.results:
                d = {}
                d['transcript'] = result.alternatives[0].transcript
                d['confidence'] = result.alternatives[0].confidence
                d['file_name'] = i
                df = df.append(d, ignore_index=True)
                print(f"File {i} results added to dataframe: {time.time() - loop_time}s")


    
    # export df of transcriptions
    df.to_csv(f'{output_path}{output_filename}', index=False)
    
    print(f"Total time elapsed: {time.time() - total_time_start}s")
    
    #return dataframe incase we would like to use it in local file
    return df

# %%
transcription_df = transcribe('./Datasets/sample_audio/Alex/',   # Indivitual INPUT PATH
                              './Datasets/sample_transcript/', # Indivitual OUTPUT PATH
                              'ALEX_nophrases_transcript.csv', # Indivitual transcription csv name
                              './Datasets/Metro_West_Streets.csv'
                             )

transcription_df
# Out:
# File sample786-25818-20200501-0442.wav opened
# [alternatives {
#   transcript: "Thursday"
#   confidence: 0.6370474100112915
# }
# language_code: "en-us"
# ]
# File sample786-25818-20200501-0442.wav results added to dataframe: 5.5439839363098145s
# File sample116-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "returning from the second alarm to go off in fact about"
#   confidence: 0.764874279499054
# }
# language_code: "en-us"
# ]
# File sample116-25818-20200501-0941.wav results added to dataframe: 4.6557838916778564s
# File sample724-25818-20200501-1210.wav opened
# []
# File sample92-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "having a t show jokes to 19219 South Street"
#   confidence: 0.6924219131469727
# }
# language_code: "en-us"
# ]
# File sample92-25818-20200501-0941.wav results added to dataframe: 3.285479784011841s
# File sample635-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "but I\'m trying to we went through a window we found a party took social housing waiting for the window"
#   confidence: 0.6430817246437073
# }
# language_code: "en-us"
# ]
# File sample635-25818-20200501-1439.wav results added to dataframe: 7.594401836395264s
# File sample697-25818-20200501-0243.wav opened
# [alternatives {
#   transcript: "407"
#   confidence: 0.6099497079849243
# }
# language_code: "en-us"
# ]
# File sample697-25818-20200501-0243.wav results added to dataframe: 1.3625900745391846s
# File sample167-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "all right"
#   confidence: 0.9128386378288269
# }
# language_code: "en-us"
# ]
# File sample167-25818-20200501-1040.wav results added to dataframe: 1.1581571102142334s
# File sample271-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "take any chance go ahead"
#   confidence: 0.7529844641685486
# }
# language_code: "en-us"
# ]
# File sample271-25818-20200501-1509.wav results added to dataframe: 1.7316160202026367s
# File sample1243-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "today"
#   confidence: 0.7116595506668091
# }
# language_code: "en-us"
# ]
# File sample1243-25818-20200501-1310.wav results added to dataframe: 1.897334098815918s
# File sample396-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "CMS said that they were told by somebody up here that they were up and they walked off and went downstairs that needs to be fine at least jumped on"
#   confidence: 0.7876013517379761
# }
# language_code: "en-us"
# ]
# File sample396-25818-20200501-1140.wav results added to dataframe: 12.267954111099243s
# File sample217-25818-20200501-0612.wav opened
# [alternatives {
#   transcript: "for calling Broadway"
#   confidence: 0.7223372459411621
# }
# language_code: "en-us"
# ]
# File sample217-25818-20200501-0612.wav results added to dataframe: 3.0083980560302734s
# File sample52-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "495 North despite a 13 sat on the 1st and 2nd traveling"
#   confidence: 0.6597369313240051
# }
# language_code: "en-us"
# ]
# File sample52-25818-20200501-1240.wav results added to dataframe: 6.6256701946258545s
# File sample851-25818-20200501-0044.wav opened
# [alternatives {
#   transcript: "we\'ll see what time did you see them on Broad Street 3 a.m. I have that thank you"
#   confidence: 0.7701449990272522
# }
# language_code: "en-us"
# ]
# File sample851-25818-20200501-0044.wav results added to dataframe: 3.8094401359558105s
# File sample611-25818-20200501-0313.wav opened
# [alternatives {
#   transcript: "for what"
#   confidence: 0.7502813339233398
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " callback"
#   confidence: 0.837799608707428
# }
# language_code: "en-us"
# ]
# File sample611-25818-20200501-0313.wav results added to dataframe: 5.201854944229126s
# File sample611-25818-20200501-0313.wav results added to dataframe: 5.208936929702759s
# File sample128-25818-20200501-0941.wav opened
# []
# File sample1022-25818-20200501-0343.wav opened
# [alternatives {
#   transcript: "all right"
#   confidence: 0.798531711101532
# }
# language_code: "en-us"
# ]
# File sample1022-25818-20200501-0343.wav results added to dataframe: 3.1115689277648926s
# File sample159-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "for the people"
#   confidence: 0.6437183618545532
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " cancel"
#   confidence: 0.8109495639801025
# }
# language_code: "en-us"
# ]
# File sample159-25818-20200501-1040.wav results added to dataframe: 6.592200040817261s
# File sample159-25818-20200501-1040.wav results added to dataframe: 6.604101896286011s
# File sample1035-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "killer Tennessee Tech"
#   confidence: 0.516787052154541
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " yes"
#   confidence: 0.8174517750740051
# }
# language_code: "en-us"
# ]
# File sample1035-25818-20200501-1110.wav results added to dataframe: 3.3896079063415527s
# File sample1035-25818-20200501-1110.wav results added to dataframe: 3.398225784301758s
# File sample1232-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "Island, 47th Street. Our address is 7173 Highland, 373 Highland Avenue"
#   confidence: 0.7267493605613708
# }
# language_code: "en-us"
# ]
# File sample1232-25818-20200501-1310.wav results added to dataframe: 12.089584827423096s
# File sample463-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "Charlie 421 else"
#   confidence: 0.5908241271972656
# }
# language_code: "en-us"
# ]
# File sample463-25818-20200501-0841.wav results added to dataframe: 3.1136109828948975s
# File sample1097-25818-20200501-0811.wav opened
# [alternatives {
#   transcript: "Thursday"
#   confidence: 0.6333763599395752
# }
# language_code: "en-us"
# ]
# File sample1097-25818-20200501-0811.wav results added to dataframe: 7.474847793579102s
# File sample412-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "not having spring for something else I\'ll"
#   confidence: 0.6648723483085632
# }
# language_code: "en-us"
# ]
# File sample412-25818-20200501-1140.wav results added to dataframe: 2.0006730556488037s
# File sample882-25818-20200501-0044.wav opened
# [alternatives {
#   transcript: "13"
#   confidence: 0.6528388857841492
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " please request at 2525 Rockdale Circle"
#   confidence: 0.7114676237106323
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 25"
#   confidence: 0.6490858793258667
# }
# language_code: "en-us"
# ]
# File sample882-25818-20200501-0044.wav results added to dataframe: 5.798418283462524s
# File sample882-25818-20200501-0044.wav results added to dataframe: 5.806013107299805s
# File sample882-25818-20200501-0044.wav results added to dataframe: 5.814697980880737s
# File sample755-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "yeah she\'s on her way home by"
#   confidence: 0.6894059181213379
# }
# language_code: "en-us"
# ]
# File sample755-25818-20200501-1210.wav results added to dataframe: 4.657138824462891s
# File sample81-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "sorry. Let me know if you self"
#   confidence: 0.6045708656311035
# }
# language_code: "en-us"
# ]
# File sample81-25818-20200501-1240.wav results added to dataframe: 1.938232183456421s
# File sample644-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "that\'s cool is that $12 Street Hyde Park letter 28 for medical assistance $12 Street Hyde Park new Xbox 3831 River and Ellis Street 1417"
#   confidence: 0.8200197219848633
# }
# language_code: "en-us"
# ]
# File sample644-25818-20200501-1439.wav results added to dataframe: 8.648366928100586s
# File sample12-25818-20200501-0413.wav opened
# [alternatives {
#   transcript: "7113 Oak Street 35414"
#   confidence: 0.5447339415550232
# }
# language_code: "en-us"
# ]
# File sample12-25818-20200501-0413.wav results added to dataframe: 3.530730962753296s
# File sample1044-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "supposed to happen and 2:40 to 1 to 5:45."
#   confidence: 0.6096339821815491
# }
# language_code: "en-us"
# ]
# File sample1044-25818-20200501-1110.wav results added to dataframe: 7.457207679748535s
# File sample820-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "all right the process of overhauling we have three lines ones closest to 37th North Street as well on the beach side of the building that\'s been locked on second floor expensive there as well with all companies were"
#   confidence: 0.8273029923439026
# }
# language_code: "en-us"
# ]
# File sample820-25818-20200501-0911.wav results added to dataframe: 8.782088041305542s
# File sample315-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "what happened to medicube response 30 Adams Ave General sickness and into meta 2:30 out of Staff General sickness check the brakes just box 3211 Lexington Street at Milton Street"
#   confidence: 0.8469858169555664
# }
# language_code: "en-us"
# ]
# File sample315-25818-20200501-1509.wav results added to dataframe: 8.423324823379517s
# File sample1290-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "watch that there are a couple of homeless body\'s findings when speaking on at the plane those okay walk over here see what"
#   confidence: 0.6933261752128601
# }
# language_code: "en-us"
# ]
# File sample1290-25818-20200501-1310.wav results added to dataframe: 6.5397257804870605s
# File sample976-25818-20200501-0143.wav opened
# []
# File sample503-25818-20200501-0113.wav opened
# [alternatives {
#   transcript: "and call you I don\'t know if your videos cutting out I\'m sure they have that beautiful"
#   confidence: 0.7023255825042725
# }
# language_code: "en-us"
# ]
# File sample503-25818-20200501-0113.wav results added to dataframe: 5.601088047027588s
# File sample1203-25818-20200501-0741.wav opened
# [alternatives {
#   transcript: "Alpha"
#   confidence: 0.6741967797279358
# }
# language_code: "en-us"
# ]
# File sample1203-25818-20200501-0741.wav results added to dataframe: 2.973507881164551s
# File sample795-25818-20200501-0911.wav opened
# []
# File sample345-25818-20200501-0712.wav opened
# [alternatives {
#   transcript: "342 Hanover Street looks like an angry customer white male Verizon gray jacket Buju crash in a store"
#   confidence: 0.8434619307518005
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " and I called them said it was a homeless mail in her walk we would be shedding and no further information as of now just now went in the call center before"
#   confidence: 0.7370980381965637
# }
# language_code: "en-us"
# ]
# File sample345-25818-20200501-0712.wav results added to dataframe: 14.162489891052246s
# File sample345-25818-20200501-0712.wav results added to dataframe: 14.168495893478394s
# File sample1173-25818-20200501-0741.wav opened
# [alternatives {
#   transcript: "Backstreet apartments ratings"
#   confidence: 0.6634998321533203
# }
# language_code: "en-us"
# ]
# File sample1173-25818-20200501-0741.wav results added to dataframe: 1.7393739223480225s
# File sample561-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "hold on"
#   confidence: 0.9128386378288269
# }
# language_code: "en-us"
# ]
# File sample561-25818-20200501-1409.wav results added to dataframe: 1.3365929126739502s
# File sample452-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "919-329-0833"
#   confidence: 0.9128385782241821
# }
# language_code: "en-us"
# ]
# File sample452-25818-20200501-0841.wav results added to dataframe: 3.853808879852295s
# File sample240-25818-20200501-0213.wav opened
# [alternatives {
#   transcript: "yes sir Apartments off"
#   confidence: 0.6684237718582153
# }
# language_code: "en-us"
# ]
# File sample240-25818-20200501-0213.wav results added to dataframe: 4.7062671184539795s
# File sample374-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "check something okay thanks. See you at"
#   confidence: 0.7356547713279724
# }
# language_code: "en-us"
# ]
# File sample374-25818-20200501-1140.wav results added to dataframe: 1.6771371364593506s
# File sample979-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "one medium see 19554"
#   confidence: 0.7211219072341919
# }
# language_code: "en-us"
# ]
# File sample979-25818-20200501-0143.wav results added to dataframe: 2.0961902141571045s
# File sample675-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "Sunday 16th Avenue Boston to afford ft-16 it\'s going to be on the left side by the entrance Samantha South"
#   confidence: 0.789935827255249
# }
# language_code: "en-us"
# ]
# File sample675-25818-20200501-1439.wav results added to dataframe: 9.15662407875061s
# File sample764-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "allowed or something"
#   confidence: 0.6398865580558777
# }
# language_code: "en-us"
# ]
# File sample764-25818-20200501-1210.wav results added to dataframe: 1.749669075012207s
# File sample293-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "cross streets having a retention unconscious 44"
#   confidence: 0.6107366681098938
# }
# language_code: "en-us"
# ]
# File sample293-25818-20200501-1509.wav results added to dataframe: 5.233710050582886s
# File sample23-25818-20200501-0413.wav opened
# [alternatives {
#   transcript: "and pull it off and just pull up in one friend"
#   confidence: 0.7063302993774414
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " employee on location getting created"
#   confidence: 0.5515758395195007
# }
# language_code: "en-us"
# ]
# File sample23-25818-20200501-0413.wav results added to dataframe: 7.070307970046997s
# File sample23-25818-20200501-0413.wav results added to dataframe: 7.077014923095703s
# File sample532-25818-20200501-0113.wav opened
# [alternatives {
#   transcript: "15 South Austin Street 58th Street South Boston Red Sox 713 a street and natural Street 0 1 0 8"
#   confidence: 0.6997470855712891
# }
# language_code: "en-us"
# ]
# File sample532-25818-20200501-0113.wav results added to dataframe: 12.103362798690796s
# File sample324-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "spirithoods freshly one looks like they\'re going to reach out"
#   confidence: 0.6213902831077576
# }
# language_code: "en-us"
# ]
# File sample324-25818-20200501-1509.wav results added to dataframe: 3.749969005584717s
# File sample811-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "for a little out of 15 hold off on that hold off on Apple"
#   confidence: 0.584299623966217
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay"
#   confidence: 0.8382395505905151
# }
# language_code: "en-us"
# ]
# File sample811-25818-20200501-0911.wav results added to dataframe: 2.6429102420806885s
# File sample811-25818-20200501-0911.wav results added to dataframe: 2.64924693107605s
# File sample1098-25818-20200501-0811.wav opened
# [alternatives {
#   transcript: "1 Sumner Street at Lyman Street for person filling space and just bring a medic one the corner of Sumner Street in Lyman Street for Christmas feelings pink nearest box number seven being mistreated language"
#   confidence: 0.7732216715812683
# }
# language_code: "en-us"
# ]
# File sample1098-25818-20200501-0811.wav results added to dataframe: 13.106395959854126s
# File sample550-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "around 3:35 in Bravos will 7 a.m. trying to get a little further off of email"
#   confidence: 0.7072798609733582
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " for accident at 4 in our West settlement"
#   confidence: 0.6451380252838135
# }
# language_code: "en-us"
# ]
# File sample550-25818-20200501-1409.wav results added to dataframe: 12.441025972366333s
# File sample550-25818-20200501-1409.wav results added to dataframe: 12.447520971298218s
# File sample1142-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "they start to finish our best for anything but give me an update an airport"
#   confidence: 0.7084903717041016
# }
# language_code: "en-us"
# ]
# File sample1142-25818-20200501-1339.wav results added to dataframe: 6.895235061645508s
# File sample944-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "patient free attention they can three conversations three zero nine fifty-one"
#   confidence: 0.5616527199745178
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 825"
#   confidence: 0.7875808477401733
# }
# language_code: "en-us"
# ]
# File sample944-25818-20200501-1011.wav results added to dataframe: 6.147781848907471s
# File sample944-25818-20200501-1011.wav results added to dataframe: 6.156836748123169s
# File sample185-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "on the other cancel missing persons"
#   confidence: 0.6485949158668518
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " it\'s the same mail. Brian or siren red menace menace okay thanks"
#   confidence: 0.7506891489028931
# }
# language_code: "en-us"
# ]
# File sample185-25818-20200501-1040.wav results added to dataframe: 6.684802055358887s
# File sample185-25818-20200501-1040.wav results added to dataframe: 6.6916139125823975s
# File sample711-25818-20200501-0243.wav opened
# [alternatives {
#   transcript: "off"
#   confidence: 0.6395062208175659
# }
# language_code: "en-us"
# ]
# File sample711-25818-20200501-0243.wav results added to dataframe: 4.593537092208862s
# File sample127-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "42"
#   confidence: 0.7728636264801025
# }
# language_code: "en-us"
# ]
# File sample127-25818-20200501-0941.wav results added to dataframe: 2.1609950065612793s
# File sample715-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "the off of the f27"
#   confidence: 0.6515349745750427
# }
# language_code: "en-us"
# ]
# File sample715-25818-20200501-1210.wav results added to dataframe: 2.2108230590820312s
# File sample156-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "not a cardiac arrest respiratory"
#   confidence: 0.724985659122467
# }
# language_code: "en-us"
# ]
# File sample156-25818-20200501-1040.wav results added to dataframe: 1.7251861095428467s
# File sample231-25818-20200501-0213.wav opened
# []
# File sample583-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "not enough to place I can go"
#   confidence: 0.6388700008392334
# }
# language_code: "en-us"
# ]
# File sample583-25818-20200501-1409.wav results added to dataframe: 3.1312308311462402s
# File sample1191-25818-20200501-0741.wav opened
# [alternatives {
#   transcript: "29 college students in college"
#   confidence: 0.5341091752052307
# }
# language_code: "en-us"
# ]
# File sample1191-25818-20200501-0741.wav results added to dataframe: 4.985860109329224s
# File sample399-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "how many people"
#   confidence: 0.6277266144752502
# }
# language_code: "en-us"
# ]
# File sample399-25818-20200501-1140.wav results added to dataframe: 2.666496753692627s
# File sample423-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "get out of this all right I have a second arrival"
#   confidence: 0.7991723418235779
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I haven\'t"
#   confidence: 0.6904953122138977
# }
# language_code: "en-us"
# ]
# File sample423-25818-20200501-0841.wav results added to dataframe: 4.507975816726685s
# File sample423-25818-20200501-0841.wav results added to dataframe: 4.512594938278198s
# File sample994-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "thanks classes will be seventeen"
#   confidence: 0.6259593367576599
# }
# language_code: "en-us"
# ]
# File sample994-25818-20200501-0143.wav results added to dataframe: 3.0028250217437744s
# File sample218-25818-20200501-0612.wav opened
# [alternatives {
#   transcript: "Public Health reporting amounts of property"
#   confidence: 0.7454116940498352
# }
# language_code: "en-us"
# ]
# File sample218-25818-20200501-0612.wav results added to dataframe: 4.603981018066406s
# File sample1272-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "at approximately 1330 to 1400 myself along with these one and the cat will be in the area"
#   confidence: 0.7722504138946533
# }
# language_code: "en-us"
# ]
# File sample1272-25818-20200501-1310.wav results added to dataframe: 5.667061805725098s
# File sample1133-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "we\'re going to make that for you"
#   confidence: 0.8153817057609558
# }
# language_code: "en-us"
# ]
# File sample1133-25818-20200501-1339.wav results added to dataframe: 1.4838218688964844s
# File sample935-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "Shell station, questions"
#   confidence: 0.6607592701911926
# }
# language_code: "en-us"
# ]
# File sample935-25818-20200501-1011.wav results added to dataframe: 3.6390748023986816s
# File sample860-25818-20200501-0044.wav opened
# [alternatives {
#   transcript: "Washington Street Jamaica Plain your Xbox 255 Washington Street 00 nineteen"
#   confidence: 0.8390346765518188
# }
# language_code: "en-us"
# ]
# File sample860-25818-20200501-0044.wav results added to dataframe: 4.085153102874756s
# File sample226-25818-20200501-0612.wav opened
# [alternatives {
#   transcript: "thank you"
#   confidence: 0.8603835105895996
# }
# language_code: "en-us"
# ]
# File sample226-25818-20200501-0612.wav results added to dataframe: 0.9035141468048096s
# File sample63-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "question mark"
#   confidence: 0.7874553799629211
# }
# language_code: "en-us"
# ]
# File sample63-25818-20200501-1240.wav results added to dataframe: 6.148058891296387s
# File sample1013-25818-20200501-0343.wav opened
# [alternatives {
#   transcript: "20 Old Road 316"
#   confidence: 0.7265399098396301
# }
# language_code: "en-us"
# ]
# File sample1013-25818-20200501-0343.wav results added to dataframe: 1.5753169059753418s
# File sample543-25818-20200501-0113.wav opened
# []
# File sample1075-25818-20200501-0811.wav opened
# [alternatives {
#   transcript: "hold on Santa Claus"
#   confidence: 0.6077667474746704
# }
# language_code: "en-us"
# ]
# File sample1075-25818-20200501-0811.wav results added to dataframe: 3.603545904159546s
# File sample119-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "2012 15:33 neighbor Street on the phone number unit 505 the medically advised to review"
#   confidence: 0.653892993927002
# }
# language_code: "en-us"
# ]
# File sample119-25818-20200501-0941.wav results added to dataframe: 10.527769088745117s
# File sample620-25818-20200501-0313.wav opened
# [alternatives {
#   transcript: "do you allow you to run into a moment check the Roman self right now there\'s nothing hey we don\'t see a fall into something else here"
#   confidence: 0.783669650554657
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay got it thank you"
#   confidence: 0.9128385186195374
# }
# language_code: "en-us"
# ]
# File sample620-25818-20200501-0313.wav results added to dataframe: 6.824528217315674s
# File sample620-25818-20200501-0313.wav results added to dataframe: 6.831735134124756s
# File sample904-25818-20200501-0642.wav opened
# []
# File sample168-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "the one on the left"
#   confidence: 0.7709333300590515
# }
# language_code: "en-us"
# ]
# File sample168-25818-20200501-1040.wav results added to dataframe: 8.418635129928589s
# File sample698-25818-20200501-0243.wav opened
# [alternatives {
#   transcript: "you know check on a 7 plus new and someone called the plan available in the trash yes"
#   confidence: 0.734490692615509
# }
# language_code: "en-us"
# ]
# File sample698-25818-20200501-0243.wav results added to dataframe: 8.183348178863525s
# File sample1000-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "going for sixteen dollars an ounce"
#   confidence: 0.5490442514419556
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " no"
#   confidence: 0.7095961570739746
# }
# language_code: "en-us"
# ]
# File sample1000-25818-20200501-0143.wav results added to dataframe: 2.137255907058716s
# File sample1000-25818-20200501-0143.wav results added to dataframe: 2.14329195022583s
# File sample1261-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "for 1 second"
#   confidence: 0.7681937217712402
# }
# language_code: "en-us"
# ]
# File sample1261-25818-20200501-1310.wav results added to dataframe: 1.0401561260223389s
# File sample987-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "Boston direct box 1598 hemenway Street at Gainsborough Street zero one twenty-two"
#   confidence: 0.8264836668968201
# }
# language_code: "en-us"
# ]
# File sample987-25818-20200501-0143.wav results added to dataframe: 7.6634521484375s
# File sample430-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "by the park plug out here"
#   confidence: 0.46482986211776733
# }
# language_code: "en-us"
# ]
# File sample430-25818-20200501-0841.wav results added to dataframe: 10.524886846542358s
# File sample134-25818-20200501-0941.wav opened
# []
# File sample702-25818-20200501-0243.wav opened
# []
# File sample1182-25818-20200501-0741.wav opened
# [alternatives {
#   transcript: "there is always open windows from the outside we just trying to confirm the actual box"
#   confidence: 0.682309627532959
# }
# language_code: "en-us"
# ]
# File sample1182-25818-20200501-0741.wav results added to dataframe: 3.416308879852295s
# File sample590-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "exactly one that\'s all the elevator 81 Essex Street Boston nearest box 1432 Hampton Inn Essex Street 1405"
#   confidence: 0.8152217864990234
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I will cancel it"
#   confidence: 0.8297253847122192
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " fortunately"
#   confidence: 0.5365329384803772
# }
# language_code: "en-us"
# ]
# File sample590-25818-20200501-1409.wav results added to dataframe: 6.752986907958984s
# File sample590-25818-20200501-1409.wav results added to dataframe: 6.759711027145386s
# File sample590-25818-20200501-1409.wav results added to dataframe: 6.764662981033325s
# File sample145-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "and then of course the first point of contact"
#   confidence: 0.8040094375610352
# }
# language_code: "en-us"
# ]
# File sample145-25818-20200501-1040.wav results added to dataframe: 8.834939002990723s
# File sample1029-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "certainly there\'s some debris in the road from South Towing on your birth mother constructive thoughts"
#   confidence: 0.6996173858642578
# }
# language_code: "en-us"
# ]
# File sample1029-25818-20200501-1110.wav results added to dataframe: 19.779237747192383s
# File sample917-25818-20200501-0642.wav opened
# [alternatives {
#   transcript: "28th March 2018"
#   confidence: 0.44874340295791626
# }
# language_code: "en-us"
# ]
# File sample917-25818-20200501-0642.wav results added to dataframe: 3.114577054977417s
# File sample738-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "mango 12"
#   confidence: 0.7886266708374023
# }
# language_code: "en-us"
# ]
# File sample738-25818-20200501-1210.wav results added to dataframe: 3.1109752655029297s
# File sample629-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "four thousand maintenance and see how soon they can get a major child"
#   confidence: 0.7394068837165833
# }
# language_code: "en-us"
# ]
# File sample629-25818-20200501-1439.wav results added to dataframe: 2.6705121994018555s
# File sample926-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "to have enough fight wanted to pay this experiment uses"
#   confidence: 0.7410849928855896
# }
# language_code: "en-us"
# ]
# File sample926-25818-20200501-1011.wav results added to dataframe: 5.211885213851929s
# File sample1120-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "1.53"
#   confidence: 0.5368084907531738
# }
# language_code: "en-us"
# ]
# File sample1120-25818-20200501-1339.wav results added to dataframe: 2.2958269119262695s
# File sample70-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "yes"
#   confidence: 0.6433013081550598
# }
# language_code: "en-us"
# ]
# File sample70-25818-20200501-1240.wav results added to dataframe: 3.7047688961029053s
# File sample873-25818-20200501-0044.wav opened
# []
# File sample367-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "Thursday"
#   confidence: 0.620882511138916
# }
# language_code: "en-us"
# ]
# File sample367-25818-20200501-1140.wav results added to dataframe: 2.89214825630188s
# File sample1058-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "how much percent is burning paper on the topic there"
#   confidence: 0.7638635039329529
# }
# language_code: "en-us"
# ]
# File sample1058-25818-20200501-1110.wav results added to dataframe: 5.343765020370483s
# File sample253-25818-20200501-0213.wav opened
# [alternatives {
#   transcript: "three levels with the 4th floor of 740 North West Los Angeles"
#   confidence: 0.725211501121521
# }
# language_code: "en-us"
# ]
# File sample253-25818-20200501-0213.wav results added to dataframe: 9.171413898468018s
# File sample196-25818-20200501-0612.wav opened
# [alternatives {
#   transcript: "324"
#   confidence: 0.7382357120513916
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " thank you for calling Blair Hartford Street"
#   confidence: 0.8184399008750916
# }
# language_code: "en-us"
# ]
# File sample196-25818-20200501-0612.wav results added to dataframe: 9.955464839935303s
# File sample196-25818-20200501-0612.wav results added to dataframe: 9.964489936828613s
# File sample309-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "I\'ll just be the sensor that just says that when you refer to it though and they take your report you want to all these responses yeah so we refer to the CFO and then they called me and said to send someone else off, things are"
#   confidence: 0.7336136102676392
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay."
#   confidence: 0.9043057560920715
# }
# language_code: "en-us"
# ]
# File sample309-25818-20200501-1509.wav results added to dataframe: 10.613747119903564s
# File sample309-25818-20200501-1509.wav results added to dataframe: 10.62243103981018s
# File sample666-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "585 response to the respiratory one they are very Street in Hyde Park one night years ago Gramercy department number for K5"
#   confidence: 0.638603925704956
# }
# language_code: "en-us"
# ]
# File sample666-25818-20200501-1439.wav results added to dataframe: 5.71276068687439s
# File sample441-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "she\'s Kelly selling for one on the orders Kelly Kelly a second alarm 55193"
#   confidence: 0.827522873878479
# }
# language_code: "en-us"
# ]
# File sample441-25818-20200501-0841.wav results added to dataframe: 9.713479042053223s
# File sample481-25818-20200501-0512.wav opened
# []
# File sample789-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "starting in the watch"
#   confidence: 0.7222933173179626
# }
# language_code: "en-us"
# ]
# File sample789-25818-20200501-0911.wav results added to dataframe: 1.4160549640655518s
# File sample1102-25818-20200501-0811.wav opened
# [alternatives {
#   transcript: "34223 alpha bravo yep so"
#   confidence: 0.7267191410064697
# }
# language_code: "en-us"
# ]
# File sample1102-25818-20200501-0811.wav results added to dataframe: 7.22471809387207s
# File sample359-25818-20200501-0712.wav opened
# [alternatives {
#   transcript: "well the cuts around back getting might have went through"
#   confidence: 0.7290406823158264
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay so 192 Warren the building to call this out there there\'s a camera on the walls they may have come through them yes 19193"
#   confidence: 0.7801806330680847
# }
# language_code: "en-us"
# ]
# File sample359-25818-20200501-0712.wav results added to dataframe: 9.93792176246643s
# File sample359-25818-20200501-0712.wav results added to dataframe: 9.943565845489502s
# File sample777-25818-20200501-0442.wav opened
# [alternatives {
#   transcript: "can I talk."
#   confidence: 0.47651511430740356
# }
# language_code: "en-us"
# ]
# File sample777-25818-20200501-0442.wav results added to dataframe: 2.227047920227051s
# File sample957-25818-20200501-1011.wav opened
# []
# File sample1151-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "I am showing up in California"
#   confidence: 0.6975659132003784
# }
# language_code: "en-us"
# ]
# File sample1151-25818-20200501-1339.wav results added to dataframe: 3.742172956466675s
# File sample496-25818-20200501-0113.wav opened
# []
# File sample30-25818-20200501-0413.wav opened
# [alternatives {
#   transcript: "organize phone"
#   confidence: 0.697775661945343
# }
# language_code: "en-us"
# ]
# File sample30-25818-20200501-0413.wav results added to dataframe: 1.283911943435669s
# File sample1066-25818-20200501-1110.wav opened
# []
# File sample280-25818-20200501-1509.wav opened
# []
# File sample802-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "went off and said like to what"
#   confidence: 0.6040695905685425
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " the driveway this"
#   confidence: 0.8033225536346436
# }
# language_code: "en-us"
# ]
# File sample802-25818-20200501-0911.wav results added to dataframe: 4.025014162063599s
# File sample802-25818-20200501-0911.wav results added to dataframe: 4.030825138092041s
# File sample749-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "CPW over to the Broadway streets out of the high school just before the entrance to the garage to the library the trash bin several bags of back"
#   confidence: 0.7141653299331665
# }
# language_code: "en-us"
# ]
# File sample749-25818-20200501-1210.wav results added to dataframe: 6.963346004486084s
# File sample521-25818-20200501-0113.wav opened
# []
# File sample658-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "strip advise the rally of potatoes has been complete all through facets except each one will be clear in your budget obviously"
#   confidence: 0.6939880847930908
# }
# language_code: "en-us"
# ]
# File sample658-25818-20200501-1439.wav results added to dataframe: 5.5956950187683105s
# File sample262-25818-20200501-0213.wav opened
# [alternatives {
#   transcript: "and looks like someone was Finding on the second floor and no apartment Midtown."
#   confidence: 0.6992309093475342
# }
# language_code: "en-us"
# ]
# File sample262-25818-20200501-0213.wav results added to dataframe: 5.1191699504852295s
# File sample499-25818-20200501-0113.wav opened
# []
# File sample657-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "15120 Huntington Avenue Boston latter fifteen and his own magical 120 Huntington Avenue Boston nearest box 1563 Huntington Ave in West Newton Street 14th"
#   confidence: 0.761005163192749
# }
# language_code: "en-us"
# ]
# File sample657-25818-20200501-1439.wav results added to dataframe: 7.744550943374634s
# File sample746-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "Grammy transgression National cooperative and subscribe"
#   confidence: 0.6128763556480408
# }
# language_code: "en-us"
# ]
# File sample746-25818-20200501-1210.wav results added to dataframe: 10.021780967712402s
# File sample891-25818-20200501-0044.wav opened
# [alternatives {
#   transcript: "I will fill up the last Twenty One can\'t"
#   confidence: 0.6214748620986938
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 2012"
#   confidence: 0.5094596147537231
# }
# language_code: "en-us"
# ]
# File sample891-25818-20200501-0044.wav results added to dataframe: 5.4180638790130615s
# File sample891-25818-20200501-0044.wav results added to dataframe: 5.430505037307739s
# File sample1084-25818-20200501-0811.wav opened
# []
# File sample470-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "one of yours up at the clouds calling out if they want"
#   confidence: 0.7123054265975952
# }
# language_code: "en-us"
# ]
# File sample470-25818-20200501-0841.wav results added to dataframe: 5.283566951751709s
# File sample778-25818-20200501-0442.wav opened
# [alternatives {
#   transcript: "the outside locations"
#   confidence: 0.6803281307220459
# }
# language_code: "en-us"
# ]
# File sample778-25818-20200501-0442.wav results added to dataframe: 2.8465559482574463s
# File sample958-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "do you want a survey in the district"
#   confidence: 0.6905689835548401
# }
# language_code: "en-us"
# ]
# File sample958-25818-20200501-1011.wav results added to dataframe: 2.2443437576293945s
# File sample401-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "no"
#   confidence: 0.8257639408111572
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " Clarence you don\'t want the same 11/28"
#   confidence: 0.6880785822868347
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " waterfall"
#   confidence: 0.6360445022583008
# }
# language_code: "en-us"
# ]
# File sample401-25818-20200501-1140.wav results added to dataframe: 10.410814046859741s
# File sample401-25818-20200501-1140.wav results added to dataframe: 10.41530704498291s
# File sample401-25818-20200501-1140.wav results added to dataframe: 10.420498847961426s
# File sample1210-25818-20200501-0741.wav opened
# [alternatives {
#   transcript: "144"
#   confidence: 0.5418494939804077
# }
# language_code: "en-us"
# ]
# File sample1210-25818-20200501-0741.wav results added to dataframe: 3.353210210800171s
# File sample1160-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "for 558 just be up there is a Home Depot you guys all over the place"
#   confidence: 0.7279630303382874
# }
# language_code: "en-us"
# ]
# File sample1160-25818-20200501-1339.wav results added to dataframe: 6.086597204208374s
# File sample572-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "broke up with magic"
#   confidence: 0.803448498249054
# }
# language_code: "en-us"
# ]
# File sample572-25818-20200501-1409.wav results added to dataframe: 2.4873158931732178s
# File sample966-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "second one I cancel if you like 3 to 1"
#   confidence: 0.7486736178398132
# }
# language_code: "en-us"
# ]
# File sample966-25818-20200501-1011.wav results added to dataframe: 2.703252077102661s
# File sample356-25818-20200501-0712.wav opened
# [alternatives {
#   transcript: "I\'m actually all channels are affected."
#   confidence: 0.6281300187110901
# }
# language_code: "en-us"
# ]
# File sample356-25818-20200501-0712.wav results added to dataframe: 2.669722080230713s
# File sample199-25818-20200501-0612.wav opened
# []
# File sample1057-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "call tomorrow. But there\'s not many universities imagining that plate vehicle description"
#   confidence: 0.6018344163894653
# }
# language_code: "en-us"
# ]
# File sample1057-25818-20200501-1110.wav results added to dataframe: 10.520411252975464s
# File sample368-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "well as you want"
#   confidence: 0.7658013105392456
# }
# language_code: "en-us"
# ]
# File sample368-25818-20200501-1140.wav results added to dataframe: 4.412849187850952s
# File sample669-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "for division one emails 1929 RAV4 respiratory to 1212 Commonwealth Avenue once you once you, have a safe, 3 on the first division one"
#   confidence: 0.7601500153541565
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " people respond at 12."
#   confidence: 0.6379913091659546
# }
# language_code: "en-us"
# ]
# File sample669-25818-20200501-1439.wav results added to dataframe: 14.304636001586914s
# File sample669-25818-20200501-1439.wav results added to dataframe: 14.309355020523071s
# File sample1221-25818-20200501-0542.wav opened
# [alternatives {
#   transcript: "4030"
#   confidence: 0.5250396728515625
# }
# language_code: "en-us"
# ]
# File sample1221-25818-20200501-0542.wav results added to dataframe: 2.2129709720611572s
# File sample510-25818-20200501-0113.wav opened
# [alternatives {
#   transcript: "want to do that occasionally outside Mandel 10 and through the morning"
#   confidence: 0.569736123085022
# }
# language_code: "en-us"
# ]
# File sample510-25818-20200501-0113.wav results added to dataframe: 6.421221017837524s
# File sample1283-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "this is like scratches out very often"
#   confidence: 0.5665082335472107
# }
# language_code: "en-us"
# ]
# File sample1283-25818-20200501-1310.wav results added to dataframe: 10.096978902816772s
# File sample306-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "but"
#   confidence: 0.8044297099113464
# }
# language_code: "en-us"
# ]
# File sample306-25818-20200501-1509.wav results added to dataframe: 4.241121768951416s
# File sample833-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "I was just updated by the inspector That\'s Heavy TV box should be here soon for the displaced residents"
#   confidence: 0.750009298324585
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " and I think it\'s"
#   confidence: 0.8746698498725891
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " explain everything 55 a medical assistance 940 Parker Street Jamaica Plain your Xbox to 390 for each Square 0 9 0 1"
#   confidence: 0.774380624294281
# }
# language_code: "en-us"
# ]
# File sample833-25818-20200501-0911.wav results added to dataframe: 9.126762866973877s
# File sample833-25818-20200501-0911.wav results added to dataframe: 9.13385009765625s
# File sample833-25818-20200501-0911.wav results added to dataframe: 9.142675876617432s
# File sample929-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "well before you take me off the 541 River Street"
#   confidence: 0.6822940111160278
# }
# language_code: "en-us"
# ]
# File sample929-25818-20200501-1011.wav results added to dataframe: 5.718164920806885s
# File sample1250-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "and it\'s going to be 10:41 until you can clearly now I\'m going to have one for you it\'s going to be 11 p.m."
#   confidence: 0.7131639719009399
# }
# language_code: "en-us"
# ]
# File sample1250-25818-20200501-1310.wav results added to dataframe: 6.898728847503662s
# File sample737-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "thank you."
#   confidence: 0.490415096282959
# }
# language_code: "en-us"
# ]
# File sample737-25818-20200501-1210.wav results added to dataframe: 8.40589427947998s
# File sample105-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "Matthew the"
#   confidence: 0.6855484843254089
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " that\'s used for needs and a baby out in the apartment the next called her and told her that the mother\'s boyfriend is heading Melissa his mother woke from a"
#   confidence: 0.6687873601913452
# }
# language_code: "en-us"
# ]
# File sample105-25818-20200501-0941.wav results added to dataframe: 6.259055852890015s
# File sample105-25818-20200501-0941.wav results added to dataframe: 6.2669677734375s
# File sample918-25818-20200501-0642.wav opened
# [alternatives {
#   transcript: "cross Trek c m s n 27 Norman"
#   confidence: 0.5976802110671997
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 725 hours in San Jose"
#   confidence: 0.6250224709510803
# }
# language_code: "en-us"
# ]
# File sample918-25818-20200501-0642.wav results added to dataframe: 11.756300926208496s
# File sample918-25818-20200501-0642.wav results added to dataframe: 11.766534090042114s
# File sample174-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "salsa salsa for West Springfield in Warren Street"
#   confidence: 0.6389178037643433
# }
# language_code: "en-us"
# ]
# File sample174-25818-20200501-1040.wav results added to dataframe: 5.0743889808654785s
# File sample684-25818-20200501-0243.wav opened
# [alternatives {
#   transcript: "can I help you"
#   confidence: 0.6912139058113098
# }
# language_code: "en-us"
# ]
# File sample684-25818-20200501-0243.wav results added to dataframe: 1.2154009342193604s
# File sample602-25818-20200501-0313.wav opened
# [alternatives {
#   transcript: "perjury in the lobby BBB District thirteen and forty-seven"
#   confidence: 0.7520976662635803
# }
# language_code: "en-us"
# ]
# File sample602-25818-20200501-0313.wav results added to dataframe: 4.558581113815308s
# File sample842-25818-20200501-0911.wav opened
# []
# File sample1026-25818-20200501-1110.wav opened
# [alternatives {
#   transcript: "to confirm that we department for 6"
#   confidence: 0.6271653175354004
# }
# language_code: "en-us"
# ]
# File sample1026-25818-20200501-1110.wav results added to dataframe: 1.8190069198608398s
# File sample385-25818-20200501-1140.wav opened
# []
# File sample1111-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "yep go ahead a light-skinned black male about five 8 we\'re in the Northeast puffy jacket off you went across the other side of the T Station on the road and jumped on a train list"
#   confidence: 0.8320266604423523
# }
# language_code: "en-us"
# ]
# File sample1111-25818-20200501-1339.wav results added to dataframe: 12.001314878463745s
# File sample988-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "that ongoing issues. Go right on it to prevent this but now you can head back and it\'s just"
#   confidence: 0.5998383164405823
# }
# language_code: "en-us"
# ]
# File sample988-25818-20200501-0143.wav results added to dataframe: 4.994045257568359s
# File sample41-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "we having all these cars are similar to the medications they seemed a little days off"
#   confidence: 0.6177659034729004
# }
# language_code: "en-us"
# ]
# File sample41-25818-20200501-1240.wav results added to dataframe: 12.23482084274292s
# File sample204-25818-20200501-0612.wav opened
# [alternatives {
#   transcript: "good morning to everyone"
#   confidence: 0.8253241777420044
# }
# language_code: "en-us"
# ]
# File sample204-25818-20200501-0612.wav results added to dataframe: 2.813464879989624s
# File sample181-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "what is out of service NBC a escape hatch on 7th Street"
#   confidence: 0.7217950820922852
# }
# language_code: "en-us"
# ]
# File sample181-25818-20200501-1040.wav results added to dataframe: 7.662071943283081s
# File sample419-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "medic 460 Seminary Ave with Southwest body building room 3724 a fault 442-8167 area code metaphor has Seminary out"
#   confidence: 0.837681770324707
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " medical responding 11:30 then"
#   confidence: 0.644631028175354
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " what\'s called an erratic it\'s going to be 93 Northbound fascinated 527-4257 comes back to a Dodge pickup truck"
#   confidence: 0.822934091091156
# }
# language_code: "en-us"
# ]
# File sample419-25818-20200501-1140.wav results added to dataframe: 17.824586868286133s
# File sample419-25818-20200501-1140.wav results added to dataframe: 17.83118987083435s
# File sample419-25818-20200501-1140.wav results added to dataframe: 17.839674711227417s
# File sample940-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "I don\'t have a m s responsible refinance cancel them at 9:40"
#   confidence: 0.6983007192611694
# }
# language_code: "en-us"
# ]
# File sample940-25818-20200501-1011.wav results added to dataframe: 6.117432117462158s
# File sample1146-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "call five zero"
#   confidence: 0.6003620624542236
# }
# language_code: "en-us"
# ]
# File sample1146-25818-20200501-1339.wav results added to dataframe: 2.603398084640503s
# File sample554-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "you take me off at Harrison Ave and that\'s our street trying to break it down home and they camp in hand and kirlyam reach out to Public Works jobs they\'re going to take as much stuff as they can but it\'s probably going to be about a leftover stuff they can send someone by here to pick up whatever remaining crashes in opposite 200 Harrison Ave right at the corner of Harrison and that\'s officer"
#   confidence: 0.8720264434814453
# }
# language_code: "en-us"
# ]
# File sample554-25818-20200501-1409.wav results added to dataframe: 12.653393983840942s
# File sample1239-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "back on our own covid-19 complex"
#   confidence: 0.8449957966804504
# }
# language_code: "en-us"
# ]
# File sample1239-25818-20200501-1310.wav results added to dataframe: 1.337622880935669s
# File sample468-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "and then your assignment a second alarm to"
#   confidence: 0.8470532894134521
# }
# language_code: "en-us"
# ]
# File sample468-25818-20200501-0841.wav results added to dataframe: 2.860785961151123s
# File sample815-25818-20200501-0911.wav opened
# []
# File sample889-25818-20200501-0044.wav opened
# [alternatives {
#   transcript: "we have emm"
#   confidence: 0.7651857137680054
# }
# language_code: "en-us"
# ]
# File sample889-25818-20200501-0044.wav results added to dataframe: 1.6455047130584717s
# File sample320-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "I printed messages since May eleventh"
# ...
# File sample1126-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "96.7. I should be all set 12:36."
#   confidence: 0.7739130258560181
# }
# language_code: "en-us"
# ]
# File sample1126-25818-20200501-1339.wav results added to dataframe: 10.49235987663269s
# File sample436-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "5114 a structure fire 39 Shell street right Engine 51 matter fourteen a structure fire 39 snow Street Brighton nearest box office 5 193 Washington Street 08"
#   confidence: 0.8206020593643188
# }
# language_code: "en-us"
# ]
# File sample436-25818-20200501-0841.wav results added to dataframe: 13.05600094795227s
# File sample981-25818-20200501-0143.wav opened
# [alternatives {
#   transcript: "24"
#   confidence: 0.6215983629226685
# }
# language_code: "en-us"
# ]
# File sample981-25818-20200501-0143.wav results added to dataframe: 2.8179709911346436s
# File sample1267-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "third floor station was activated I just reset it will just I think Bravo was checking the front lobby and see if that\'s not the yes"
#   confidence: 0.7301052808761597
# }
# language_code: "en-us"
# ]
# File sample1267-25818-20200501-1310.wav results added to dataframe: 10.955219030380249s
# File sample48-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "play water at 8:10 a.m. our colorful Longwood"
#   confidence: 0.6649929881095886
# }
# language_code: "en-us"
# ]
# File sample48-25818-20200501-1240.wav results added to dataframe: 4.928916931152344s
# File sample1118-25818-20200501-1339.wav opened
# []
# File sample143-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "instead of Concord"
#   confidence: 0.49678128957748413
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 323."
#   confidence: 0.7505218982696533
# }
# language_code: "en-us"
# ]
# File sample143-25818-20200501-1040.wav results added to dataframe: 11.02391004562378s
# File sample143-25818-20200501-1040.wav results added to dataframe: 11.030865907669067s
# File sample898-25818-20200501-0642.wav opened
# [alternatives {
#   transcript: "Fox Meadows to Ocean or good morning"
#   confidence: 0.6803625226020813
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " good morning"
#   confidence: 0.8973426222801208
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " Massachusetts Avenue Roxbury your Xbox 727 Massachusetts Avenue South Hampton Street 06422"
#   confidence: 0.7956145405769348
# }
# language_code: "en-us"
# ]
# File sample898-25818-20200501-0642.wav results added to dataframe: 8.742877960205078s
# File sample898-25818-20200501-0642.wav results added to dataframe: 8.750203847885132s
# File sample898-25818-20200501-0642.wav results added to dataframe: 8.75564694404602s
# File sample596-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "okay I\'ve never came by before 6:00"
#   confidence: 0.6105731725692749
# }
# language_code: "en-us"
# ]
# File sample596-25818-20200501-1409.wav results added to dataframe: 14.240303993225098s
# File sample1184-25818-20200501-0741.wav opened
# []
# File sample704-25818-20200501-0243.wav opened
# []
# File sample132-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "she was doing and privacy"
#   confidence: 0.5479463338851929
# }
# language_code: "en-us"
# ]
# File sample132-25818-20200501-0941.wav results added to dataframe: 8.027474880218506s
# File sample897-25818-20200501-0642.wav opened
# []
# File sample844-25818-20200501-0911.wav opened
# [alternatives {
#   transcript: "Can Knockdown companies are overhauling and techniques are sentenced including the exposure at 37 Hill Street will notify Red Cross and the bath assistance unit step seven adult mental stuff"
#   confidence: 0.8063623905181885
# }
# language_code: "en-us"
# ]
# File sample844-25818-20200501-0911.wav results added to dataframe: 10.970117092132568s
# File sample920-25818-20200501-0642.wav opened
# []
# File sample604-25818-20200501-0313.wav opened
# [alternatives {
#   transcript: "all right captain my captain for an injured officer"
#   confidence: 0.7911044359207153
# }
# language_code: "en-us"
# ]
# File sample604-25818-20200501-0313.wav results added to dataframe: 7.167277812957764s
# File sample47-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "a lot of static respiratory distress 1089 Dorchester Avenue Dorchester your Xbox 1862 Dorchester and Savin Hill Avenue 1216"
#   confidence: 0.8114415407180786
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " anyone returning"
#   confidence: 0.72730952501297
# }
# language_code: "en-us"
# ]
# File sample47-25818-20200501-1240.wav results added to dataframe: 7.824256896972656s
# File sample47-25818-20200501-1240.wav results added to dataframe: 7.830657958984375s
# File sample1268-25818-20200501-1310.wav opened
# []
# File sample202-25818-20200501-0612.wav opened
# []
# File sample682-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "hello I have a door off and well some certain workers were moving to this page and in a sense to all the way back"
#   confidence: 0.7010630369186401
# }
# language_code: "en-us"
# ]
# File sample682-25818-20200501-1439.wav results added to dataframe: 15.743366718292236s
# File sample439-25818-20200501-0841.wav opened
# [alternatives {
#   transcript: "I know street signs, 481 a structure fire 39 South Street Brighton nearest box 5193 Washington Street zero eight twenty-eight"
#   confidence: 0.8137462735176086
# }
# language_code: "en-us"
# ]
# File sample439-25818-20200501-0841.wav results added to dataframe: 10.52276873588562s
# File sample383-25818-20200501-1140.wav opened
# [alternatives {
#   transcript: "Cardiac Arrest John West Broadway South Boston laterally a cardiac arrest 9 West Broadway South Boston Red Sox 7138 Dorchester Ave and West Broadway 1118"
#   confidence: 0.6837683916091919
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " some of the screen Arnold singer Associates for the commercial Central Station higher levels president\'s office number seven Beacon Street"
#   confidence: 0.7134569883346558
# }
# language_code: "en-us"
# ]
# File sample383-25818-20200501-1140.wav results added to dataframe: 13.447553157806396s
# File sample383-25818-20200501-1140.wav results added to dataframe: 13.453357219696045s
# File sample1117-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "everything numbers for Gilmer I think I have that vehicle from the airport early and collecting 307"
#   confidence: 0.7664464116096497
# }
# language_code: "en-us"
# ]
# File sample1117-25818-20200501-1339.wav results added to dataframe: 8.81775712966919s
# File sample1256-25818-20200501-1310.wav opened
# [alternatives {
#   transcript: "our lot of times the Central Station aligned 100 South Huntington Avenue Jamaica Plain nearest Fox23 18th Street and South Huntington Ave Grill"
#   confidence: 0.7332518100738525
# }
# language_code: "en-us"
# ]
# File sample1256-25818-20200501-1310.wav results added to dataframe: 7.06991982460022s
# File sample79-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "383 Calvert Avenue in Chelsa 383 Talbot Ave 12:30 for 22"
#   confidence: 0.7419872283935547
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " please"
#   confidence: 0.6447638273239136
# }
# language_code: "en-us"
# ]
# File sample79-25818-20200501-1240.wav results added to dataframe: 5.47254204750061s
# File sample79-25818-20200501-1240.wav results added to dataframe: 5.48053503036499s
# File sample1129-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "I hope you with are you question for tonight"
#   confidence: 0.6154406666755676
# }
# language_code: "en-us"
# ]
# File sample1129-25818-20200501-1339.wav results added to dataframe: 3.65981125831604s
# File sample172-25818-20200501-1040.wav opened
# [alternatives {
#   transcript: "please"
#   confidence: 0.720391035079956
# }
# language_code: "en-us"
# ]
# File sample172-25818-20200501-1040.wav results added to dataframe: 2.149923801422119s
# File sample731-25818-20200501-1210.wav opened
# []
# File sample103-25818-20200501-0941.wav opened
# [alternatives {
#   transcript: "for that moving Department 45 Short Street"
#   confidence: 0.6617210507392883
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay one go ahead and look forward to call back in a call from CarMax in the house instead just as long as boys with her"
#   confidence: 0.7370868921279907
# }
# language_code: "en-us"
# ]
# File sample103-25818-20200501-0941.wav results added to dataframe: 31.188249111175537s
# File sample103-25818-20200501-0941.wav results added to dataframe: 31.194599151611328s
# File sample1009-25818-20200501-0343.wav opened
# [alternatives {
#   transcript: "zero fourth floor off of that individual as a 7-Eleven I get past five for what what is Mother want us to do"
#   confidence: 0.7642725110054016
# }
# language_code: "en-us"
# ]
# File sample1009-25818-20200501-0343.wav results added to dataframe: 8.877665996551514s
# File sample960-25818-20200501-1011.wav opened
# [alternatives {
#   transcript: "thirties thin feels about six feet tall and curly blonde hair black jacket black pants"
#   confidence: 0.6697890162467957
# }
# language_code: "en-us"
# ]
# File sample960-25818-20200501-1011.wav results added to dataframe: 3.3826000690460205s
# File sample599-25818-20200501-0313.wav opened
# []
# File sample350-25818-20200501-0712.wav opened
# [alternatives {
#   transcript: "103 over here and I believe it is a system handprints on the window of the Texas Georgia you this right before the rain"
#   confidence: 0.6887443661689758
# }
# language_code: "en-us"
# ]
# File sample350-25818-20200501-0712.wav results added to dataframe: 12.218345880508423s
# File sample1166-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "City you have that 15 minutes goes all the way"
#   confidence: 0.6451345086097717
# }
# language_code: "en-us"
# ]
# File sample1166-25818-20200501-1339.wav results added to dataframe: 3.203932046890259s
# File sample574-25818-20200501-1409.wav opened
# [alternatives {
#   transcript: "way in Las Vegas for a Ford in white outside Pizza"
#   confidence: 0.6647738814353943
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 48 more than when"
#   confidence: 0.7532415986061096
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 2014"
#   confidence: 0.686629056930542
# }
# language_code: "en-us"
# ]
# File sample574-25818-20200501-1409.wav results added to dataframe: 5.0843329429626465s
# File sample574-25818-20200501-1409.wav results added to dataframe: 5.091400861740112s
# File sample574-25818-20200501-1409.wav results added to dataframe: 5.098331689834595s
# File sample36-25818-20200501-1240.wav opened
# [alternatives {
#   transcript: "Peter. San Jose"
#   confidence: 0.5683789253234863
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I have"
#   confidence: 0.7730767726898193
# }
# language_code: "en-us"
# ]
# File sample36-25818-20200501-1240.wav results added to dataframe: 11.128838062286377s
# File sample36-25818-20200501-1240.wav results added to dataframe: 11.135244131088257s
# File sample448-25818-20200501-0841.wav opened
# []
# File sample488-25818-20200501-0512.wav opened
# [alternatives {
#   transcript: "taking off and Landing with his father"
#   confidence: 0.6538318991661072
# }
# language_code: "en-us"
# ]
# File sample488-25818-20200501-0512.wav results added to dataframe: 14.205796957015991s
# File sample835-25818-20200501-0911.wav opened
# []
# File sample300-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "I know"
#   confidence: 0.6724793314933777
# }
# language_code: "en-us"
# ]
# File sample300-25818-20200501-1509.wav results added to dataframe: 2.7223548889160156s
# File sample1285-25818-20200501-1310.wav opened
# []
# File sample1227-25818-20200501-0542.wav opened
# [alternatives {
#   transcript: "after 4:31"
#   confidence: 0.4898080825805664
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I sent me off with the 111"
#   confidence: 0.6720182299613953
# }
# language_code: "en-us"
# ]
# File sample1227-25818-20200501-0542.wav results added to dataframe: 6.606656074523926s
# File sample1227-25818-20200501-0542.wav results added to dataframe: 6.6170032024383545s
# File sample516-25818-20200501-0113.wav opened
# []
# File sample1051-25818-20200501-1110.wav opened
# []
# File sample740-25818-20200501-1210.wav opened
# [alternatives {
#   transcript: "1085 Washburn residential enforcement or"
#   confidence: 0.6953288316726685
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I spoke with a female who want to verify"
#   confidence: 0.870327353477478
# }
# language_code: "en-us"
# ]
# File sample740-25818-20200501-1210.wav results added to dataframe: 3.975083112716675s
# File sample740-25818-20200501-1210.wav results added to dataframe: 3.9837958812713623s
# File sample528-25818-20200501-0113.wav opened
# [alternatives {
#   transcript: "I just went for I don\'t know magical 7th Street Columbia Road Dorchester ends in 2490 call dentistry and Columbia Road Dorchester irresponsible 3113 Columbia Road at 25010"
#   confidence: 0.8153626918792725
# }
# language_code: "en-us"
# ]
# File sample528-25818-20200501-0113.wav results added to dataframe: 15.283928871154785s
# File sample1219-25818-20200501-0542.wav opened
# [alternatives {
#   transcript: "I\'m glad that after new part number five."
#   confidence: 0.6406015157699585
# }
# language_code: "en-us"
# ]
# File sample1219-25818-20200501-0542.wav results added to dataframe: 10.039077997207642s
# File sample651-25818-20200501-1439.wav opened
# [alternatives {
#   transcript: "I\'m sorry"
#   confidence: 0.7510954737663269
# }
# language_code: "en-us"
# ]
# File sample651-25818-20200501-1439.wav results added to dataframe: 1.3527030944824219s
# File sample264-25818-20200501-0213.wav opened
# [alternatives {
#   transcript: "division one"
#   confidence: 0.8618513941764832
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " did you want to have"
#   confidence: 0.5863452553749084
# }
# language_code: "en-us"
# ]
# File sample264-25818-20200501-0213.wav results added to dataframe: 1.8051831722259521s
# File sample264-25818-20200501-0213.wav results added to dataframe: 1.8113901615142822s
# File sample289-25818-20200501-1509.wav opened
# [alternatives {
#   transcript: "Parts Roxbury 18-14 been unconscious perfect Massachusetts Avenue and Bell Boulevard Roxbury nearest box 727 Massachusetts Avenue South Hancock 1448"
#   confidence: 0.763939380645752
# }
# language_code: "en-us"
# ]
# File sample289-25818-20200501-1509.wav results added to dataframe: 10.01974892616272s
# File sample407-25818-20200501-1140.wav opened
# []
# File sample1158-25818-20200501-1339.wav opened
# [alternatives {
#   transcript: "at 10:20 for Matt Groening brother"
#   confidence: 0.7123615741729736
# }
# language_code: "en-us"
# ]
# File sample1158-25818-20200501-1339.wav results added to dataframe: 3.0089762210845947s
# File sample1082-25818-20200501-0811.wav opened
# []
# Total time elapsed: 7875.397683143616s
#       confidence                           file_name  \
# 0       0.637047   sample786-25818-20200501-0442.wav
# 1       0.764874   sample116-25818-20200501-0941.wav
# 2       0.692422    sample92-25818-20200501-0941.wav
# 3       0.643082   sample635-25818-20200501-1439.wav
# 4       0.609950   sample697-25818-20200501-0243.wav
# ...          ...                                 ...
# 1443    0.751095   sample651-25818-20200501-1439.wav
# 1444    0.861851   sample264-25818-20200501-0213.wav
# 1445    0.586345   sample264-25818-20200501-0213.wav
# 1446    0.763939   sample289-25818-20200501-1509.wav
# 1447    0.712362  sample1158-25818-20200501-1339.wav
#
#                                              transcript
# 0                                              Thursday
# 1     returning from the second alarm to go off in f...
# 2           having a t show jokes to 19219 South Street
# 3     but I'm trying to we went through a window we ...
# 4                                                   407
# ...                                                 ...
# 1443                                          I'm sorry
# 1444                                       division one
# 1445                               did you want to have
# 1446  Parts Roxbury 18-14 been unconscious perfect M...
# 1447                 at 10:20 for Matt Groening brother
#
# [1448 rows x 3 columns]

# %%
# Out:
# 'car locations required to be outside in the motor vehicle'
