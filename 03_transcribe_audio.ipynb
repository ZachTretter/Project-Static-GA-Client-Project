# %%
# pip install --upgrade google-cloud-speech
import os
import io
from google.cloud import speech_v1p1beta1 as speech
from google.cloud.speech_v1p1beta1 import enums
from pydub import AudioSegment
import pandas as pd
import time

# %%
# Check audio file properites
sound_file = AudioSegment.from_file('./Datasets/sample_audio/0501-1240sample3.wav', format="wav")

print(f'Sample Width: {sound_file.sample_width}')
print(f'Channel Count: {sound_file.channels}')
print(f'Duration: {len(sound_file) / 1000}s')
print(f'Sample Rate: {sound_file.frame_rate}')
print(f'Sample Rate: {sound_file.dBFS}')
# Out:
# Sample Width: 2
# Channel Count: 1
# Duration: 27.63s
# Sample Rate: 22050
# Sample Rate: -27.58092973651456

# %%
def transcribe(input_path,output_path,output_filename):
    # define key path (security feature)
    os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/Users/alex/ga-dsi-11/police-scanner-speech-to-text-c09b11750e4e.json'
    
    # Instantiate speech to text model, DataFrame, and time
    client = speech.SpeechClient()
    df = pd.DataFrame()
    total_time_start = time.time()
    
    # loop through files in our input path
    for i in os.listdir(input_path):
        if i.endswith('.wav'):
            loop_time = time.time()
            
            # open our audio file
            with io.open(f'{input_path}{i}', 'rb') as audio_file:
                content = audio_file.read()
                audio = speech.types.RecognitionAudio(content=content)
            print(f"File {i} opened")
            
            # model parameters
            config = speech.types.RecognitionConfig(
                encoding=enums.RecognitionConfig.AudioEncoding.LINEAR16,
                sample_rate_hertz = sound_file.frame_rate,
                language_code = 'en-US',
                audio_channel_count = sound_file.channels,
                enable_separate_recognition_per_channel = True,
                use_enhanced = True,
                model = 'phone_call',
                speech_contexts = [{'boost': 20.0}])
            
            # This models equivalent of fit/predict
            response = client.recognize(config, audio)
            
            # build dictionary -> dataframe
#             print(response.results)
            for result in response.results:
                d = {}
                d['transcript'] = result.alternatives[0].transcript
                d['confidence_interval'] = result.alternatives[0].confidence
                d['file_name'] = i
                df = df.append(d, ignore_index=True)
                print(f"File {i} results added to dataframe: {time.time() - loop_time}s")


    
    # export df of transcriptions
    df.to_csv(f'{output_path}{output_filename}', index=False)
    
    print(f"Total time elapsed: {time.time() - total_time_start}s")
    
    #return dataframe incase we would like to use it in local folder
    return df

# %%
transcription_df = transcribe('./Datasets/sample_audio/', './Datasets/sample_transcript/', 'full_sample_transcript.csv')
# Out:
# File 0501-1240sample22.wav opened
# [alternatives {
#   transcript: "question mark"
#   confidence: 0.7874553799629211
# }
# language_code: "en-us"
# ]
# File 0501-1240sample22.wav results added to dataframe: 5.9480509757995605s
# File 0501-1240sample36.wav opened
# []
# File 0501-1240sample7.wav opened
# [alternatives {
#   transcript: "we having all these cars are similar to the medications they seemed a little days off"
#   confidence: 0.6177639961242676
# }
# language_code: "en-us"
# ]
# File 0501-1240sample7.wav results added to dataframe: 17.015205144882202s
# File 0501-1240sample6.wav opened
# [alternatives {
#   transcript: "fls you on with the road for another clue"
#   confidence: 0.618201494216919
# }
# language_code: "en-us"
# ]
# File 0501-1240sample6.wav results added to dataframe: 7.523545026779175s
# File 0501-1240sample37.wav opened
# [alternatives {
#   transcript: "play the area of seven to White Street for a mail that"
#   confidence: 0.7448995113372803
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " open up people\'s car doors or people\'s houses I\'m sorry blackmailing is 30 is about five feet and built beige colored jacket white T-shirt"
#   confidence: 0.7860385179519653
# }
# language_code: "en-us"
# ]
# File 0501-1240sample37.wav results added to dataframe: 7.751405954360962s
# File 0501-1240sample37.wav results added to dataframe: 7.7565388679504395s
# File 0501-1240sample23.wav opened
# [alternatives {
#   transcript: "already one scene man we got two offices down there"
#   confidence: 0.5908806324005127
# }
# language_code: "en-us"
# ]
# File 0501-1240sample23.wav results added to dataframe: 2.122371196746826s
# File 0501-1240sample35.wav opened
# []
# File 0501-1240sample21.wav opened
# [alternatives {
#   transcript: "1515 hold on Truxel Vania Avenue in Crown Point"
#   confidence: 0.658115029335022
# }
# language_code: "en-us"
# ]
# File 0501-1240sample21.wav results added to dataframe: 8.60364580154419s
# File 0501-1240sample4.wav opened
# [alternatives {
#   transcript: "stop someone else\'s reaction time coming to work involved in several years"
#   confidence: 0.5739578604698181
# }
# language_code: "en-us"
# ]
# File 0501-1240sample4.wav results added to dataframe: 9.115162134170532s
# File 0501-1240sample5.wav opened
# [alternatives {
#   transcript: "selling is clear that."
#   confidence: 0.7220759987831116
# }
# language_code: "en-us"
# ]
# File 0501-1240sample5.wav results added to dataframe: 12.492783784866333s
# File 0501-1240sample20.wav opened
# [alternatives {
#   transcript: "but individual running away from try to catch up with us"
#   confidence: 0.7564845681190491
# }
# language_code: "en-us"
# ]
# File 0501-1240sample20.wav results added to dataframe: 4.813578128814697s
# File 0501-1240sample34.wav opened
# [alternatives {
#   transcript: "character is called the guy that we were able to fix this don\'t have like a fragment Okay so"
#   confidence: 0.6849549412727356
# }
# language_code: "en-us"
# ]
# File 0501-1240sample34.wav results added to dataframe: 8.306406021118164s
# File 0501-1240sample18.wav opened
# [alternatives {
#   transcript: "cardiac disorders 1190 Adams Street Dorchester hedging 16 a cardiac disorder who recognized the Adams Street Dorchester your Xbox 3471 West 5th Street."
#   confidence: 0.7528998255729675
# }
# language_code: "en-us"
# ]
# File 0501-1240sample18.wav results added to dataframe: 12.585137128829956s
# File 0501-1240sample30.wav opened
# [alternatives {
#   transcript: "Kip Moore the respiratory 29 Saratoga Street East Boston Gemini\'s Saratoga one of your comments and 12 Thirty one eight seven"
#   confidence: 0.6934331059455872
# }
# language_code: "en-us"
# ]
# File 0501-1240sample30.wav results added to dataframe: 7.054037094116211s
# File 0501-1240sample24.wav opened
# [alternatives {
#   transcript: "174 Delta Force Toyota black and color choice"
#   confidence: 0.8100232481956482
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 15 and 1/2 * number to 12:20"
#   confidence: 0.7666040062904358
# }
# language_code: "en-us"
# ]
# File 0501-1240sample24.wav results added to dataframe: 10.960248231887817s
# File 0501-1240sample24.wav results added to dataframe: 10.96359920501709s
# File 0501-1240sample1.wav opened
# [alternatives {
#   transcript: "4th and eleven fifty hours in recent years Seventeen and twelve seconds"
#   confidence: 0.7588353157043457
# }
# language_code: "en-us"
# ]
# File 0501-1240sample1.wav results added to dataframe: 7.620828866958618s
# File 0501-1240sample25.wav opened
# [alternatives {
#   transcript: "Fairmont Avenue Mattapan your Xbox 360 7, is highway at Brookhaven Street to 12"
#   confidence: 0.7010067105293274
# }
# language_code: "en-us"
# ]
# File 0501-1240sample25.wav results added to dataframe: 6.822842836380005s
# File 0501-1240sample31.wav opened
# [alternatives {
#   transcript: "now that\'s better watch television"
#   confidence: 0.5957862734794617
# }
# language_code: "en-us"
# ]
# File 0501-1240sample31.wav results added to dataframe: 3.807013988494873s
# File 0501-1240sample19.wav opened
# [alternatives {
#   transcript: "that can come out from a district"
#   confidence: 0.6002892255783081
# }
# language_code: "en-us"
# ]
# File 0501-1240sample19.wav results added to dataframe: 1.9269721508026123s
# File 0501-1240sample27.wav opened
# [alternatives {
#   transcript: "yes"
#   confidence: 0.6433011293411255
# }
# language_code: "en-us"
# ]
# File 0501-1240sample27.wav results added to dataframe: 4.142687797546387s
# File 0501-1240sample33.wav opened
# [alternatives {
#   transcript: "383 Calvert Avenue in Chelsa 383 Talbot Ave 12:30 for 22"
#   confidence: 0.7419872879981995
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " please"
#   confidence: 0.6447638273239136
# }
# language_code: "en-us"
# ]
# File 0501-1240sample33.wav results added to dataframe: 5.19022011756897s
# File 0501-1240sample33.wav results added to dataframe: 5.195693254470825s
# File 0501-1240sample2.wav opened
# [alternatives {
#   transcript: "to advise the Rocksino and orange alert system"
#   confidence: 0.6855254173278809
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " hi Miranda. What"
#   confidence: 0.5550129413604736
# }
# language_code: "en-us"
# ]
# File 0501-1240sample2.wav results added to dataframe: 12.877993106842041s
# File 0501-1240sample2.wav results added to dataframe: 12.883427143096924s
# File 0501-1240sample3.wav opened
# [alternatives {
#   transcript: "Peter. San Jose"
#   confidence: 0.5683789253234863
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I have"
#   confidence: 0.773076593875885
# }
# language_code: "en-us"
# ]
# File 0501-1240sample3.wav results added to dataframe: 13.082371234893799s
# File 0501-1240sample3.wav results added to dataframe: 13.087377309799194s
# File 0501-1240sample32.wav opened
# [alternatives {
#   transcript: "I want X1 in the area of 33901, D Rose Ave between jamesway Masala Street cell phone 911 call 911 line weren\'t able to call"
#   confidence: 0.8108665347099304
# }
# language_code: "en-us"
# ]
# File 0501-1240sample32.wav results added to dataframe: 7.184678077697754s
# File 0501-1240sample26.wav opened
# [alternatives {
#   transcript: "the ISTA want to reach out to the school police and see if they can take any of that to get an address from you was a grandma\'s house and locked up because you can call and I\'ll I\'ll save me some Frozen okay did you know what school to go"
#   confidence: 0.7679322957992554
# }
# language_code: "en-us"
# ]
# File 0501-1240sample26.wav results added to dataframe: 15.061393022537231s
# File 0501-1240sample41.wav opened
# [alternatives {
#   transcript: "Island, 27th Street. Our address is 7501 East 34783 Highland, 373 Highland Ave."
#   confidence: 0.7339600920677185
# }
# language_code: "en-us"
# ]
# File 0501-1240sample41.wav results added to dataframe: 11.154336929321289s
# File 0501-1240sample40.wav opened
# [alternatives {
#   transcript: "that\'s the number for the factory all right on a little bit and if any calls come in that tells me to take it to the mtpd SX what the internet right now"
#   confidence: 0.675569474697113
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " and then my number is 202-203-0523"
#   confidence: 0.8598076105117798
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " okay I\'ll be right now if it comes in for anybody else will play but he\'s at the empty together"
#   confidence: 0.7286158800125122
# }
# language_code: "en-us"
# ]
# File 0501-1240sample40.wav results added to dataframe: 15.539583921432495s
# File 0501-1240sample40.wav results added to dataframe: 15.546778917312622s
# File 0501-1240sample40.wav results added to dataframe: 15.551685810089111s
# File 0501-1240sample42.wav opened
# [alternatives {
#   transcript: "the island aftermath reality"
#   confidence: 0.7066814303398132
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 12:30"
#   confidence: 0.6494860649108887
# }
# language_code: "en-us"
# ]
# File 0501-1240sample42.wav results added to dataframe: 8.615243911743164s
# File 0501-1240sample42.wav results added to dataframe: 8.620067119598389s
# File 0501-1240sample43.wav opened
# [alternatives {
#   transcript: "that\'s Community Springfield I know there\'s a couple of cars off in the area anyway even the tools for you maybe the one-on-one so there is two on 1 second"
#   confidence: 0.667500913143158
# }
# language_code: "en-us"
# ]
# File 0501-1240sample43.wav results added to dataframe: 7.571887969970703s
# File 0501-1240sample17.wav opened
# [alternatives {
#   transcript: "nineteen eighty-two and the cardiac Florida 1190 Adams Street Dorchester 1119 Adams Rd, 12:20 to see mm 1190 Adams"
#   confidence: 0.773810625076294
# }
# language_code: "en-us"
# ]
# File 0501-1240sample17.wav results added to dataframe: 11.880066871643066s
# File 0501-1240sample16.wav opened
# [alternatives {
#   transcript: "24 monitor comments please"
#   confidence: 0.7052135467529297
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " I meant probably have one for you two stroke five bolts into the lane and Drug Testing of a 5 volt. Lane gently stroked 12:19 to 12"
#   confidence: 0.7815411686897278
# }
# language_code: "en-us"
# ]
# File 0501-1240sample16.wav results added to dataframe: 10.757632970809937s
# File 0501-1240sample16.wav results added to dataframe: 10.762614965438843s
# File 0501-1240sample14.wav opened
# [alternatives {
#   transcript: "okay"
#   confidence: 0.9128385782241821
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " 495 North Friday the Thirteenth battling the first and second choice I tried on a lot."
#   confidence: 0.609281599521637
# }
# language_code: "en-us"
# ]
# File 0501-1240sample14.wav results added to dataframe: 11.867702960968018s
# File 0501-1240sample14.wav results added to dataframe: 11.872650861740112s
# File 0501-1240sample28.wav opened
# []
# File 0501-1240sample29.wav opened
# [alternatives {
#   transcript: "answering some recommend you show the alarm company on Steam as well as regular companies. It\'s a lot of the shutdown German a command to 731-373-1470. So make the repairs terminated 12"
#   confidence: 0.828542947769165
# }
# language_code: "en-us"
# ]
# File 0501-1240sample29.wav results added to dataframe: 15.577079057693481s
# File 0501-1240sample15.wav opened
# [alternatives {
#   transcript: "495 North despite a 13 sat on the 1st and 2nd traveling"
#   confidence: 0.6597193479537964
# }
# language_code: "en-us"
# ]
# File 0501-1240sample15.wav results added to dataframe: 8.895808935165405s
# File 0501-1240sample39.wav opened
# [alternatives {
#   transcript: "okay for resources program in the past and today too"
#   confidence: 0.7354837656021118
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " yes"
#   confidence: 0.9128385782241821
# }
# language_code: "en-us"
# ]
# File 0501-1240sample39.wav results added to dataframe: 6.4877588748931885s
# File 0501-1240sample39.wav results added to dataframe: 6.492646932601929s
# File 0501-1240sample11.wav opened
# [alternatives {
#   transcript: "a lot of static respiratory distress 1089 Dorchester Avenue Dorchester your Xbox 1862 Dorchester and Savin Hill Avenue 1216"
#   confidence: 0.8114415407180786
# }
# language_code: "en-us"
# , alternatives {
#   transcript: " anyone returning"
#   confidence: 0.72730952501297
# }
# language_code: "en-us"
# ]
# File 0501-1240sample11.wav results added to dataframe: 7.623794078826904s
# File 0501-1240sample11.wav results added to dataframe: 7.628926038742065s
# File 0501-1240sample8.wav opened
# [alternatives {
#   transcript: "diagrama Street Apartment, 12:40 p.m."
#   confidence: 0.6355605721473694
# }
# language_code: "en-us"
# ]
# File 0501-1240sample8.wav results added to dataframe: 6.752017021179199s
# File 0501-1240sample9.wav opened
# [alternatives {
#   transcript: "I\'m 21 up the street you never once touched police department calling it in so we\'ll be checking employees who haven\'t been embarked Book 2 weeks left work without some symptom that\'s been able to get typical of them still in the land of fonzo thirty years old selling it for"
#   confidence: 0.700143575668335
# }
# language_code: "en-us"
# ]
# File 0501-1240sample9.wav results added to dataframe: 18.93869400024414s
# File 0501-1240sample10.wav opened
# []
# File 0501-1240sample38.wav opened
# [alternatives {
#   transcript: "124 Ricker Road General statements involve in and check your notes and for instance there are spots 1241 Arlington Street at Ricker Road"
#   confidence: 0.8019618391990662
# }
# language_code: "en-us"
# ]
# File 0501-1240sample38.wav results added to dataframe: 10.861571073532104s
# File 0501-1240sample12.wav opened
# [alternatives {
#   transcript: "play water at 8:10 a.m. our colorful Longwood"
#   confidence: 0.6649929285049438
# }
# language_code: "en-us"
# ]
# File 0501-1240sample12.wav results added to dataframe: 6.343721389770508s
# File 0501-1240sample13.wav opened
# [alternatives {
#   transcript: "Saturday 72nd Street"
#   confidence: 0.5350797772407532
# }
# language_code: "en-us"
# ]
# File 0501-1240sample13.wav results added to dataframe: 2.7648909091949463s
# Total time elapsed: 361.1581130027771s
