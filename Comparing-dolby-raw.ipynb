# %%
import pandas as pd

# %%
raw = pd.read_csv('./Datasets/dolby_tests/raw-test-df.csv')
enhanced = pd.read_csv('./Datasets/dolby_tests/enhanced-test-df.csv')

# %%
raw
# Out:
#                            file_name  audio_length  transcribe_time  \
# 0   sample40-25818-20200501-1210.wav           1.2              4.3
# 1   sample31-25818-20200501-1210.wav           1.2              6.8
# 2   sample31-25818-20200501-1210.wav           1.2              6.8
# 3    sample1-25818-20200501-1210.wav           1.2             16.9
# 4    sample1-25818-20200501-1210.wav           1.2             16.9
# ..                               ...           ...              ...
# 61  sample55-25818-20200501-1210.wav           1.2             14.8
# 62   sample8-25818-20200501-1210.wav           1.2              1.8
# 63  sample24-25818-20200501-1210.wav           1.2              9.3
# 64  sample24-25818-20200501-1210.wav           1.2              9.3
# 65  sample24-25818-20200501-1210.wav           1.2              9.3
#
#     confidence                                         transcript
# 0     0.801794                the owner wants the fuk up a little
# ...

# %%
enhanced
# Out:
#                                     file_name  audio_length  transcribe_time  \
# 0   sample27-enhanced-25818-20200501-1210.wav           1.2             10.1
# 1   sample27-enhanced-25818-20200501-1210.wav           1.2             10.1
# 2   sample27-enhanced-25818-20200501-1210.wav           1.2             10.2
# 3    sample4-enhanced-25818-20200501-1210.wav           1.2              2.0
# 4   sample10-enhanced-25818-20200501-1210.wav           1.2             12.7
# ..                                        ...           ...              ...
# 62  sample43-enhanced-25818-20200501-1210.wav           1.2              8.3
# 63  sample29-enhanced-25818-20200501-1210.wav           1.2             11.2
# 64  sample36-enhanced-25818-20200501-1210.wav           1.2              5.2
# 65  sample47-enhanced-25818-20200501-1210.wav           1.2             13.1
# 66  sample47-enhanced-25818-20200501-1210.wav           1.2             13.1
#
# ...

# %%
enhanced.sort_values('file_name').head(60)
# Out:
#                                     file_name  audio_length  transcribe_time  \
# 42   sample1-enhanced-25818-20200501-1210.wav           1.2              9.8
# 4   sample10-enhanced-25818-20200501-1210.wav           1.2             12.7
# 5   sample10-enhanced-25818-20200501-1210.wav           1.2             12.7
# 43  sample11-enhanced-25818-20200501-1210.wav           1.2              0.9
# 56  sample12-enhanced-25818-20200501-1210.wav           1.2              4.3
# 27  sample13-enhanced-25818-20200501-1210.wav           1.2              4.8
# 8   sample14-enhanced-25818-20200501-1210.wav           1.2              3.1
# 9   sample14-enhanced-25818-20200501-1210.wav           1.2              3.1
# 40  sample15-enhanced-25818-20200501-1210.wav           1.2              3.3
# 32  sample17-enhanced-25818-20200501-1210.wav           1.2              4.7
# 12  sample18-enhanced-25818-20200501-1210.wav           1.2              2.4
# ...

# %%
raw.sort_values('file_name').head(60)
# Out:
#                            file_name  audio_length  transcribe_time  \
# 3    sample1-25818-20200501-1210.wav           1.2             16.9
# 4    sample1-25818-20200501-1210.wav           1.2             16.9
# 5    sample1-25818-20200501-1210.wav           1.2             16.9
# 33  sample10-25818-20200501-1210.wav           1.2             11.4
# 34  sample10-25818-20200501-1210.wav           1.2             11.4
# 54  sample11-25818-20200501-1210.wav           1.2              1.6
# 6   sample13-25818-20200501-1210.wav           1.2              4.0
# 22  sample14-25818-20200501-1210.wav           1.2              3.1
# 59  sample15-25818-20200501-1210.wav           1.2              4.2
# 17  sample17-25818-20200501-1210.wav           1.2              6.3
# 11  sample18-25818-20200501-1210.wav           1.2              1.4
# 32   sample2-25818-20200501-1210.wav           1.2             13.2
# 53  sample20-25818-20200501-1210.wav           1.2              2.4
# ...
